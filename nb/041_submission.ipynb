# %% [markdown]
# # Overview
# - nb039ベース
# - nb040で作ったrfcの結果を使用する

# %% [markdown]
# # Const

# %%
NB = '041'
isSmallSet = False
if isSmallSet:
    LENGTH = 7000
else:
    LENGTH = 500_000

PATH_TRAIN = './../data/input/train_clean.csv'
PATH_TEST = './../data/input/test_clean.csv'
PATH_SMPLE_SUB = './../data/input/sample_submission.csv'
DIR_OUTPUT = './../data/output/'
DIR_OUTPUT_IGNORE = './../data/output_ignore/'
cp = ['#f8b195', '#f67280', '#c06c84', '#6c5b7b', '#355c7d']
sr = 10*10**3  # 10 kHz

# %% [markdown]
# # Import everything I need :)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import gc
import random
import os
import itertools
import multiprocessing
import numpy as np
from scipy import signal
# from pykalman import KalmanFilter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fastprogress import progress_bar
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold, train_test_split, StratifiedKFold, GroupKFold
from sklearn.metrics import f1_score, mean_absolute_error, confusion_matrix
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
# from sklearn.svm import SVR
from sklearn.linear_model import Lasso
# from dtreeviz.trees import dtreeviz
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
# import tensorflow_addons as tfa

# %% [markdown]
# # My function

# %%
def f1_macro(true, pred):
    return f1_score(true, pred, average='macro')

def get_df_batch(df, batch):
    idxs = df['batch'] == batch
    assert any(idxs), 'そのようなbatchはありません'
    return df[idxs]
    
def get_signal_mv_mean(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).mean().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_std(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).std().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_min(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).min().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_max(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).max().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv



def group_feat_train(_train):
    train = _train.copy()
    # group init
    train['group'] = int(0)

    # group 1
    idxs = (train['batch'] == 3) | (train['batch'] == 7)
    train['group'][idxs] = int(1)

    # group 2
    idxs = (train['batch'] == 5) | (train['batch'] == 8)
    train['group'][idxs] = int(2)

    # group 3
    idxs = (train['batch'] == 2) | (train['batch'] == 6)
    train['group'][idxs] = int(3)

    # group 4
    idxs = (train['batch'] == 4) | (train['batch'] == 9)
    train['group'][idxs] = int(4)
    
    return train[['group']]

def group_feat_test(_test):
    test = _test.copy()
    
    # group init
    test['group'] = int(0)
    x_idx = np.arange(len(test))

    # group 1
    idxs = (100000<=x_idx) & (x_idx<200000)
    test['group'][idxs] = int(1)
    idxs = (900000<=x_idx) & (x_idx<=1000000)
    test['group'][idxs] = int(1)

    # group 2
    idxs = (200000<=x_idx) & (x_idx<300000)
    test['group'][idxs] = int(2)
    idxs = (600000<=x_idx) & (x_idx<700000)
    test['group'][idxs] = int(2)

    # group 3
    idxs = (400000<=x_idx) & (x_idx<500000)
    test['group'][idxs] = int(3)

    # group 4
    idxs = (500000<=x_idx) & (x_idx<600000)
    test['group'][idxs] = int(4)
    idxs = (700000<=x_idx) & (x_idx<800000)
    test['group'][idxs] = int(4)
    
    return test[['group']]


class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, X_valid, y_valid):
        self.n_feat = len(X_valid.columns)
        if self.metric == 'auc':
            y_valid_score = self.model.predict_proba(X_valid)[:, 1]
            fpr, tpr, thresholds = roc_curve(y_valid, y_valid_score)
            self.base_score = auc(fpr, tpr)
        else:
            pred = np.round(self.model.predict(X_valid)).astype('int8')
            self.base_score = self.metric(y_valid, pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(X_valid.columns):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            y_valid_pred = self.model.predict(df_perm)
            if self.metric == 'auc':
                y_valid_score = self.model.predict_proba(df_perm)[:, 1]
                fpr, tpr, thresholds = roc_curve(y_valid, y_valid_score)
                score = auc(fpr, tpr)
            else:
                score = self.metric(y_valid, np.round(y_valid_pred).astype('int8'))
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')

def plot_corr(df, abs_=False, threshold=0.95):
    if abs_==True:
        corr = df.corr().abs()>threshold
        vmin = 0
    else:
        corr = df.corr()
        vmin = -1

    # Plot
    fig, ax = plt.subplots(figsize=(12, 10), dpi=100)
    fig.patch.set_facecolor('white')
    sns.heatmap(corr,
                xticklabels=df.corr().columns,
                yticklabels=df.corr().columns,
                vmin=vmin,
                vmax=1,
                center=0, 
                annot=False)

    # Decorations
    ax.set_title('Correlation', fontsize=22)

def get_low_corr_column(df, threshold):

    df_corr = df.corr()
    df_corr = abs(df_corr)
    columns = df_corr.columns

    # 対角線の値を0にする
    for i in range(0, len(columns)):
        df_corr.iloc[i, i] = 0

    while True:
        columns = df_corr.columns
        max_corr = 0.0
        query_column = None
        target_column = None

        df_max_column_value = df_corr.max()
        max_corr = df_max_column_value.max()
        query_column = df_max_column_value.idxmax()
        target_column = df_corr[query_column].idxmax()

        if max_corr < threshold:
            # しきい値を超えるものがなかったため終了
            break
        else:
            # しきい値を超えるものがあった場合
            delete_column = None
            saved_column = None

            # その他との相関の絶対値が大きい方を除去
            if sum(df_corr[query_column]) <= sum(df_corr[target_column]):
                delete_column = target_column
                saved_column = query_column
            else:
                delete_column = query_column
                saved_column = target_column

            # 除去すべき特徴を相関行列から消す（行、列）
            df_corr.drop([delete_column], axis=0, inplace=True)
            df_corr.drop([delete_column], axis=1, inplace=True)

    return df_corr.columns  # 相関が高い特徴量を除いた名前リスト

def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        if col!='open_channels':
            col_type = df[col].dtypes
            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()
                if str(col_type)[:3] == 'int':
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def train_lgbm(X, y, X_te, lgbm_params, random_state=5, n_fold=5, verbose=50, early_stopping_rounds=100, show_fig=True):
    # using features
    print(f'features({len(X.columns)}): \n{X.columns}') if not verbose==0 else None

#     folds = KFold(n_splits=n_fold, shuffle=True, random_state=random_state)
    folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=random_state)

    scores = []
    oof = np.zeros(len(X))
    oof_round = np.zeros(len(X))
    test_pred = np.zeros(len(X_te))
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for fold_n, (train_idx, valid_idx) in enumerate(folds.split(X, y=y)):
        if  verbose==0:
            pass
        else:
            print('\n------------------')
            print(f'- Fold {fold_n + 1}/{N_FOLD} started at {time.ctime()}')

        # prepare dataset
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]

        # train
        model = LGBMRegressor(**lgbm_params, n_estimators=N_ESTIMATORS)
        model.fit(X_train, y_train,
                  eval_set=[(X_train, y_train), (X_valid, y_valid)],
                  verbose=verbose,
                  early_stopping_rounds=early_stopping_rounds)

        # pred
        y_valid_pred = model.predict(X_valid, model.best_iteration_)
        y_valid_pred_round = np.round(y_valid_pred).astype('int8')
        _test_pred = model.predict(X_te, model.best_iteration_)

        if show_fig==False:
            pass
        else:
            # permutation importance
            pi = permutation_importance(model, f1_macro) # model と metric を渡す
            pi.compute(X_valid, y_valid)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])

        # result
        oof[valid_idx] = y_valid_pred
        oof_round[valid_idx] = y_valid_pred_round
        score = f1_score(y_valid, y_valid_pred_round, average='macro')
        scores.append(score)
        test_pred += _test_pred
        if verbose==0:
            pass
        else:
            print(f'---> f1-score(macro) valid: {f1_score(y_valid, y_valid_pred_round, average="macro"):.4f}')
            print('')


    print('====== finish ======')
    print('score list:', scores)
    print('CV mean score(f1_macro): {0:.4f}, std: {1:.4f}'.format(np.mean(scores), np.std(scores)))
    print(f'oof score(f1_macro): {f1_score(y, oof_round, average="macro"):.4f}')
    print('')


    if show_fig==False:
        pass
    else:
        # visualization
        plt.figure(figsize=(5, 5))
        plt.plot([0, 10], [0, 10], color='gray')
        plt.scatter(y, oof, alpha=0.05, color=cp[1])
        plt.xlabel('true')
        plt.ylabel('pred')
        plt.show()
          
        # confusion_matrix
        plot_confusion_matrix(y, oof_round, classes=np.arange(11))
        
        
        # permutation importance
        plt.figure(figsize=(15, int(0.25*len(X.columns))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=False)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()

    # submission
    test_pred = test_pred/N_FOLD
    test_pred_round = np.round(test_pred).astype('int8')
      
    return test_pred_round, test_pred, oof_round, oof

def plot_confusion_matrix(truth, pred, classes, normalize=False, title=''):
    cm = confusion_matrix(truth, pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    plt.figure(figsize=(10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix', size=15)
    plt.colorbar(fraction=0.046, pad=0.04)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.grid(False)
    plt.tight_layout()

# %%
def train_test_split_lgbm(X, y, X_te, lgbm_params, random_state=5, test_size=0.3, verbose=50, early_stopping_rounds=100, show_fig=True):
    # using features
    print(f'features({len(X.columns)}): \n{X.columns}') if not verbose==0 else None

#     folds = KFold(n_splits=n_fold, shuffle=True, random_state=random_state)
#     folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=random_state)
    
    # prepare dataset
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # train
    model = LGBMRegressor(**lgbm_params, n_estimators=N_ESTIMATORS)
    model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_valid, y_valid)],
              verbose=verbose,
              early_stopping_rounds=early_stopping_rounds)

    # pred
    oof = model.predict(X_valid, model.best_iteration_)
    oof_round = np.round(oof).astype('int8')
    test_pred = model.predict(X_te, model.best_iteration_)
    test_pred_round = np.round(test_pred).astype('int8')

    print('====== finish ======')
    print(f'oof score(f1_macro): {f1_score(y_valid, oof_round, average="macro"):.4f}')
    print('')


    if show_fig==False:
        pass
    else:
        # visualization
        plt.figure(figsize=(5, 5))
        plt.plot([0, 10], [0, 10], color='gray')
        plt.scatter(y_valid, oof, alpha=0.05, color=cp[1])
        plt.xlabel('true')
        plt.ylabel('pred')
        plt.show()
          
        # confusion_matrix
        plot_confusion_matrix(y_valid, oof_round, classes=np.arange(11))
        
        # permutation importance
        pi = permutation_importance(model, f1_macro) # model と metric を渡す
        pi.compute(X_valid, y_valid)
        pi.show_permutation_importance(score_type='accuracy')  # loss or accuracy
        plt.show()

    return test_pred_round, test_pred, oof_round, oof

# %% [markdown]
# <br>
#
# ref: https://www.kaggle.com/martxelo/fe-and-ensemble-mlp-and-lgbm

# %%
def calc_gradients(s, n_grads=4):
    '''
    Calculate gradients for a pandas series. Returns the same number of samples
    '''
    grads = pd.DataFrame()
    
    g = s.values
    for i in range(n_grads):
        g = np.gradient(g)
        grads['grad_' + str(i+1)] = g
        
    return grads


def calc_low_pass(s, n_filts=10):
    '''
    Applies low pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.3, n_filts)
#     wns = [0.3244]
    
    low_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='low')
        zi = signal.lfilter_zi(b, a)
        low_pass['lowpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        low_pass['lowpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return low_pass

def calc_high_pass(s, n_filts=10):
    '''
    Applies high pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.1, n_filts)
#     wns = [0.0100, 0.0264, 0.0699, 0.3005, 0.4885, 0.7943]
    
    high_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='high')
        zi = signal.lfilter_zi(b, a)
        high_pass['highpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        high_pass['highpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return high_pass

def calc_roll_stats(s, windows=[10, 50, 100, 500, 1000, 3000]):
    '''
    Calculates rolling stats like mean, std, min, max...
    '''
    roll_stats = pd.DataFrame()
    for w in windows:
        roll_stats['roll_mean_' + str(w)] = s.rolling(window=w, min_periods=1).mean().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_std_' + str(w)] = s.rolling(window=w, min_periods=1).std().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_min_' + str(w)] = s.rolling(window=w, min_periods=1).min().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_max_' + str(w)] = s.rolling(window=w, min_periods=1).max().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_range_' + str(w)] = roll_stats['roll_max_' + str(w)] - roll_stats['roll_min_' + str(w)]
        roll_stats['roll_q10_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.10).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q25_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.25).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q50_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.50).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q75_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.75).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q90_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.90).interpolate('spline', order=5, limit_direction='both')
    
    # add zeros when na values (std)
#     roll_stats = roll_stats.fillna(value=0)
             
    return roll_stats

def calc_ewm(s, windows=[10, 50, 100, 500, 1000, 3000]):
    '''
    Calculates exponential weighted functions
    '''
    ewm = pd.DataFrame()
    for w in windows:
        ewm['ewm_mean_' + str(w)] = s.ewm(span=w, min_periods=1).mean()
        ewm['ewm_std_' + str(w)] = s.ewm(span=w, min_periods=1).std()
        
    # add zeros when na values (std)
    ewm = ewm.fillna(value=0)
        
    return ewm



def divide_and_add_features(s, signal_size=500000):
    '''
    Divide the signal in bags of "signal_size".
    Normalize the data dividing it by 15.0
    '''
    # normalize
    s = s/15.0
    
    ls = []
    for i in progress_bar(range(int(s.shape[0]/signal_size))):
        sig = s[i*signal_size:(i+1)*signal_size].copy().reset_index(drop=True)
        sig_featured = add_features(sig)
        ls.append(sig_featured)
    
    return pd.concat(ls, axis=0)

# %% [markdown]
# <br>
#
# ref: https://www.kaggle.com/nxrprime/single-model-lgbm-kalman-filter-ii

# %%
def Kalman1D(observations,damping=1):
    # To return the smoothed time series data
    observation_covariance = damping
    initial_value_guess = observations[0]
    transition_matrix = 1
    transition_covariance = 0.1
    initial_value_guess
    kf = KalmanFilter(
            initial_state_mean=initial_value_guess,
            initial_state_covariance=observation_covariance,
            observation_covariance=observation_covariance,
            transition_covariance=transition_covariance,
            transition_matrices=transition_matrix
        )
    pred_state, state_cov = kf.smooth(observations)
    return pred_state

# %% [markdown]
# # Preparation

# %% [markdown]
# setting

# %%
sns.set()

# %% [markdown]
# <br>
#
# load dataset

# %% [raw]
# df_tr = pd.read_csv(PATH_TRAIN)
# df_te = pd.read_csv(PATH_TEST)

# %% [markdown]
# <br>
#
# 処理のしやすさのために、バッチ番号を振る

# %% [raw]
# batch_list = []
# for n in range(10):
#     batchs = np.ones(500000)*n
#     batch_list.append(batchs.astype(int))
# batch_list = np.hstack(batch_list)
# df_tr['batch'] = batch_list
#
# batch_list = []
# for n in range(4):
#     batchs = np.ones(500000)*n
#     batch_list.append(batchs.astype(int))
# batch_list = np.hstack(batch_list)
# df_te['batch'] = batch_list

# %% [markdown]
# <br>
#
# smallset?

# %% [raw]
# if isSmallSet:
#     print('small set mode')
#     # train
#     batchs = df_tr['batch'].values
#     dfs = []
#     for i_bt, bt in enumerate(df_tr['batch'].unique()):
#         idxs = batchs == bt
#         _df = df_tr[idxs][:LENGTH].copy()
#         dfs.append(_df)
#     df_tr = pd.concat(dfs).reset_index(drop=True)
#
#     # test
#     batchs = df_te['batch'].values
#     dfs = []
#     for i_bt, bt in enumerate(df_te['batch'].unique()):
#         idxs = batchs == bt
#         _df = df_te[idxs][:LENGTH].copy()
#         dfs.append(_df)
#     df_te = pd.concat(dfs).reset_index(drop=True)

# %% [markdown]
# # Train

# %%
# configurations and main hyperparammeters
# EPOCHS = 180
EPOCHS = 180
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 321
LR = 0.0015
SPLITS = 6

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
#     tf.random.set_seed(seed)

# %%
# read data
def read_data():
    train = pd.read_csv(PATH_TRAIN, dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv(PATH_TEST, dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv(PATH_SMPLE_SUB, dtype={'time': np.float32})
    
#     Y_train_proba = np.load('./../data/input/Y_train_proba.npy')
#     Y_test_proba = np.load('./../data/input/Y_test_proba.npy')
    probas = np.load('./../data/output_ignore/probas_nb040_RandomForestClassifier_cv_0.9378.npz')
    Y_train_proba = probas['arr_0']
    Y_test_proba = probas['arr_1']
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]
        
#     group1のスパイクを削除df_tr
#     batch_list = []
#     for n in range(10):
#         batchs = np.ones(500000)*n
#         batch_list.append(batchs.astype(int))
#     batch_list = np.hstack(batch_list)
#     train['batch'] = batch_list
#     max_ = train.loc[train['batch']==3]['signal'].max() 
#     min_ = train.loc[train['batch']==3]['signal'].min() 
#     idxs = (train['batch']==7) & (train['signal']>max_)
#     train['signal'][idxs] = max_
#     idxs = (train['batch']==7) & (train['signal']<min_)
#     train['signal'][idxs] = min_
#     train = train.drop(['batch'], axis=1)

    # add offset
    batch_list = []
    for n in range(10):
        batchs = np.ones(500000)*n
        batch_list.append(batchs.astype(int))
    batch_list = np.hstack(batch_list)
    train['batch'] = batch_list
    batch_list = []
    for n in range(4):
        batchs = np.ones(500000)*n
        batch_list.append(batchs.astype(int))
    batch_list = np.hstack(batch_list)
    test['batch'] = batch_list
    
    group = group_feat_train(train)
    train = pd.concat([train, group], axis=1)
    group = group_feat_test(test)
    test = pd.concat([test, group], axis=1)
    
    off_set_4 = 0.952472 - (-1.766044)
    off_set_9 = 0.952472 - (-1.770441)
    # batch4
    idxs = train['batch'] == 4
    train['signal'][idxs] = train['signal'].values + off_set_4
    # batch9
    idxs = train['batch'] == 9
    train['signal'][idxs] = train['signal'].values + off_set_9
    
    off_set_test = 2.750
    # group4
    idxs = test['group'] == 4
    test['signal'][idxs] = test['signal'][idxs].values + off_set_test
    
    plt.figure(figsize=(20, 3))
    plt.plot(train['signal'])
    plt.show()
    plt.figure(figsize=(20, 3))
    plt.plot(test['signal'])
    plt.show()
    
    train = train.drop(['batch', 'group'], axis=1)
    test = test.drop(['batch', 'group'], axis=1)
    return train, test, sub

# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    train_input_mean = train.signal.mean()
    train_input_sigma = train.signal.std()
    train['signal'] = (train.signal - train_input_mean) / train_input_sigma
    test['signal'] = (test.signal - train_input_mean) / train_input_sigma
    return train, test

# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)
    # create leads and lags (1, 2, 3 making them 6 features)
    df = lag_with_pct_change(df, [1, 2, 3])
    # create signal ** 2 (this is the new feature)
    df['signal_2'] = df['signal'] ** 2
    return df

# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# model function (very important, you can try different arquitectures to get a better score. I believe that top public leaderboard is a 1D Conv + RNN style)
def Classifier(shape_):
    
    def cbr(x, out_layer, kernel, stride, dilation):
        x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        return x
    
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters = filters,
                   kernel_size = 1,
                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = Multiply()([tanh_out, sigm_out])
            x = Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = Add()([res_x, x])
        return res_x
    
    inp = Input(shape = (shape_))
    x = cbr(inp, 64, 7, 1, 1)
    x = BatchNormalization()(x)
    x = wave_block(x, 16, 3, 12)
    x = BatchNormalization()(x)
    x = wave_block(x, 32, 3, 8)
    x = BatchNormalization()(x)
    x = wave_block(x, 64, 3, 4)
    x = BatchNormalization()(x)
    x = wave_block(x, 128, 3, 1)
    x = cbr(x, 32, 7, 1, 1)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    out = Dense(11, activation = 'softmax', name = 'out')(x)
    
    model = models.Model(inputs = inp, outputs = out)
    
    opt = Adam(lr = LR)
#     opt = tfa.optimizers.SWA(opt)
#     model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    model.compile(loss = categorical_crossentropy, optimizer = opt, metrics = ['accuracy'])
    return model

# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    else:
        lr = LR / 100
    return lr

# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')

# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
#     config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, 
#                                       gpu_options=tf.compat.v1.GPUOptions(
#                                       visible_device_list='4', # specify GPU number
#                                       allow_growth=True
#                                       )
#                                      )
#     sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
#     tf.compat.v1.keras.backend.set_session(sess)
    # tf.compat.v1 ---> tf  (tensorflow2系からtensorflow1系に変更)
    config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, 
#                                       gpu_options=tf.GPUOptions(
#                                       visible_device_list='4', # specify GPU number
#                                       allow_growth=True
#                                       )
                                     )
    sess = tf.Session(graph=tf.get_default_graph(), config=config)
    tf.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')

        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        model = Classifier(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 2,
                  validation_data = (valid_x,valid_y))
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    
    # submission
    save_path = f'{DIR_OUTPUT}submission_nb{NB}_cv_{f1_score_:.4f}.csv'
    print(f'submission save path: {save_path}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv(save_path, index=False, float_format='%.4f')
    
    # probas
    save_path = f'{DIR_OUTPUT_IGNORE}probas_nb{NB}_cv_{f1_score_:.4f}'
    print(f'probas save path: {save_path}')
    np.savez_compressed(save_path, oof_, preds_)

    return oof_

# %%
# %%time
# this function run our entire program
def run_everything():
    
    print(f'Reading Data Started...({time.ctime()})')
    train, test, sample_submission = read_data()
    train, test = normalize(train, test)
    print(f'Reading and Normalizing Data Completed')
        
    print(f'Creating Features({time.ctime()})')
    print(f'Feature Engineering Started...')
    train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
    test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)
    train, test, features = feature_selection(train, test)
    print(f'Feature Engineering Completed...')
        
   
    print(f'Training Wavenet model with {SPLITS} folds of GroupKFold Started...({time.ctime()})')
    oof_ = run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
    print(f'Training completed...')
    
    return oof_
        
oof_ = run_everything()
# Out:
# Reading Data Started...(Thu May  7 07:34:21 2020)
# Reading and Normalizing Data Completed
# Creating Features(Thu May  7 07:34:31 2020)
# Feature Engineering Started...
# Feature Engineering Completed...
# Training Wavenet model with 6 folds of GroupKFold Started...(Thu May  7 07:34:39 2020)
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.80369
#  - 22s - loss: 0.5645 - acc: 0.8431 - val_loss: 0.8282 - val_acc: 0.9239
# Epoch 2/180
# F1 Macro Score: 0.86640
#  - 9s - loss: 0.1852 - acc: 0.9580 - val_loss: 0.4798 - val_acc: 0.9445
# Epoch 3/180
# F1 Macro Score: 0.91411
#  - 8s - loss: 0.1435 - acc: 0.9643 - val_loss: 0.2343 - val_acc: 0.9604
# Epoch 4/180
# F1 Macro Score: 0.93279
#  - 8s - loss: 0.1303 - acc: 0.9654 - val_loss: 0.1479 - val_acc: 0.9650
# Epoch 5/180
# F1 Macro Score: 0.93490
#  - 7s - loss: 0.1231 - acc: 0.9662 - val_loss: 0.1234 - val_acc: 0.9655
# Epoch 6/180
# F1 Macro Score: 0.93658
#  - 7s - loss: 0.1202 - acc: 0.9663 - val_loss: 0.1101 - val_acc: 0.9661
# Epoch 7/180
# F1 Macro Score: 0.93664
#  - 7s - loss: 0.1157 - acc: 0.9666 - val_loss: 0.1089 - val_acc: 0.9661
# Epoch 8/180
# F1 Macro Score: 0.93775
#  - 7s - loss: 0.1122 - acc: 0.9668 - val_loss: 0.1023 - val_acc: 0.9664
# Epoch 9/180
# F1 Macro Score: 0.92976
#  - 7s - loss: 0.1113 - acc: 0.9666 - val_loss: 0.1220 - val_acc: 0.9624
# Epoch 10/180
# F1 Macro Score: 0.92640
#  - 7s - loss: 0.1111 - acc: 0.9662 - val_loss: 0.1318 - val_acc: 0.9622
# Epoch 11/180
# F1 Macro Score: 0.92027
#  - 7s - loss: 0.1720 - acc: 0.9534 - val_loss: 0.1659 - val_acc: 0.9576
# Epoch 12/180
# F1 Macro Score: 0.93388
#  - 7s - loss: 0.1313 - acc: 0.9640 - val_loss: 0.1269 - val_acc: 0.9643
# Epoch 13/180
# F1 Macro Score: 0.93747
#  - 7s - loss: 0.1143 - acc: 0.9668 - val_loss: 0.1035 - val_acc: 0.9663
# Epoch 14/180
# F1 Macro Score: 0.93719
#  - 7s - loss: 0.1129 - acc: 0.9666 - val_loss: 0.1048 - val_acc: 0.9662
# Epoch 15/180
# F1 Macro Score: 0.93779
#  - 7s - loss: 0.1081 - acc: 0.9671 - val_loss: 0.1003 - val_acc: 0.9665
# Epoch 16/180
# F1 Macro Score: 0.93731
#  - 7s - loss: 0.1065 - acc: 0.9672 - val_loss: 0.1012 - val_acc: 0.9662
# Epoch 17/180
# F1 Macro Score: 0.93664
#  - 7s - loss: 0.1047 - acc: 0.9672 - val_loss: 0.1027 - val_acc: 0.9659
# Epoch 18/180
# F1 Macro Score: 0.93640
#  - 7s - loss: 0.1041 - acc: 0.9671 - val_loss: 0.1014 - val_acc: 0.9658
# Epoch 19/180
# F1 Macro Score: 0.93724
#  - 7s - loss: 0.1036 - acc: 0.9672 - val_loss: 0.0989 - val_acc: 0.9663
# Epoch 20/180
# F1 Macro Score: 0.93747
#  - 7s - loss: 0.1008 - acc: 0.9674 - val_loss: 0.0967 - val_acc: 0.9665
# Epoch 21/180
# F1 Macro Score: 0.93732
#  - 7s - loss: 0.1006 - acc: 0.9673 - val_loss: 0.0985 - val_acc: 0.9663
# Epoch 22/180
# F1 Macro Score: 0.93785
#  - 7s - loss: 0.1007 - acc: 0.9672 - val_loss: 0.0941 - val_acc: 0.9666
# Epoch 23/180
# F1 Macro Score: 0.93748
#  - 7s - loss: 0.0989 - acc: 0.9674 - val_loss: 0.0964 - val_acc: 0.9664
# Epoch 24/180
# F1 Macro Score: 0.93669
#  - 7s - loss: 0.0974 - acc: 0.9675 - val_loss: 0.0984 - val_acc: 0.9660
# Epoch 25/180
# F1 Macro Score: 0.93777
#  - 7s - loss: 0.0983 - acc: 0.9672 - val_loss: 0.0936 - val_acc: 0.9665
# Epoch 26/180
# F1 Macro Score: 0.93661
#  - 7s - loss: 0.0972 - acc: 0.9674 - val_loss: 0.0957 - val_acc: 0.9661
# Epoch 27/180
# F1 Macro Score: 0.93777
#  - 7s - loss: 0.0996 - acc: 0.9671 - val_loss: 0.0925 - val_acc: 0.9667
# Epoch 28/180
# F1 Macro Score: 0.93656
#  - 7s - loss: 0.0954 - acc: 0.9675 - val_loss: 0.0956 - val_acc: 0.9662
# Epoch 29/180
# F1 Macro Score: 0.93747
#  - 7s - loss: 0.0956 - acc: 0.9674 - val_loss: 0.0933 - val_acc: 0.9664
# Epoch 30/180
# F1 Macro Score: 0.93736
#  - 7s - loss: 0.0943 - acc: 0.9675 - val_loss: 0.0924 - val_acc: 0.9664
# Epoch 31/180
# F1 Macro Score: 0.93750
#  - 7s - loss: 0.0937 - acc: 0.9676 - val_loss: 0.0921 - val_acc: 0.9665
# Epoch 32/180
# F1 Macro Score: 0.93816
#  - 7s - loss: 0.0924 - acc: 0.9677 - val_loss: 0.0897 - val_acc: 0.9669
# Epoch 33/180
# F1 Macro Score: 0.93721
#  - 7s - loss: 0.0915 - acc: 0.9678 - val_loss: 0.0908 - val_acc: 0.9666
# Epoch 34/180
# F1 Macro Score: 0.93810
#  - 7s - loss: 0.0915 - acc: 0.9678 - val_loss: 0.0888 - val_acc: 0.9670
# Epoch 35/180
# F1 Macro Score: 0.93809
#  - 7s - loss: 0.0914 - acc: 0.9678 - val_loss: 0.0889 - val_acc: 0.9669
# Epoch 36/180
# F1 Macro Score: 0.93747
#  - 7s - loss: 0.0911 - acc: 0.9679 - val_loss: 0.0910 - val_acc: 0.9665
# Epoch 37/180
# F1 Macro Score: 0.93787
#  - 7s - loss: 0.0914 - acc: 0.9678 - val_loss: 0.0898 - val_acc: 0.9667
# Epoch 38/180
# F1 Macro Score: 0.93808
#  - 7s - loss: 0.0903 - acc: 0.9679 - val_loss: 0.0890 - val_acc: 0.9669
# Epoch 39/180
# F1 Macro Score: 0.93719
#  - 7s - loss: 0.0935 - acc: 0.9674 - val_loss: 0.0923 - val_acc: 0.9664
# Epoch 40/180
# F1 Macro Score: 0.93717
#  - 7s - loss: 0.0907 - acc: 0.9679 - val_loss: 0.0902 - val_acc: 0.9665
# Epoch 41/180
# F1 Macro Score: 0.93836
#  - 7s - loss: 0.0901 - acc: 0.9680 - val_loss: 0.0880 - val_acc: 0.9671
# Epoch 42/180
# F1 Macro Score: 0.93862
#  - 7s - loss: 0.0890 - acc: 0.9681 - val_loss: 0.0880 - val_acc: 0.9672
# Epoch 43/180
# F1 Macro Score: 0.93681
#  - 7s - loss: 0.0897 - acc: 0.9679 - val_loss: 0.0898 - val_acc: 0.9666
# Epoch 44/180
# F1 Macro Score: 0.93786
#  - 7s - loss: 0.0898 - acc: 0.9679 - val_loss: 0.0886 - val_acc: 0.9668
# Epoch 45/180
# F1 Macro Score: 0.93814
#  - 7s - loss: 0.0893 - acc: 0.9680 - val_loss: 0.0879 - val_acc: 0.9669
# Epoch 46/180
# F1 Macro Score: 0.93765
#  - 7s - loss: 0.0893 - acc: 0.9680 - val_loss: 0.0883 - val_acc: 0.9669
# Epoch 47/180
# F1 Macro Score: 0.93848
#  - 7s - loss: 0.0891 - acc: 0.9680 - val_loss: 0.0873 - val_acc: 0.9671
# Epoch 48/180
# F1 Macro Score: 0.93851
#  - 7s - loss: 0.0889 - acc: 0.9680 - val_loss: 0.0869 - val_acc: 0.9672
# Epoch 49/180
# F1 Macro Score: 0.93834
#  - 7s - loss: 0.0886 - acc: 0.9681 - val_loss: 0.0875 - val_acc: 0.9671
# Epoch 50/180
# F1 Macro Score: 0.93818
#  - 7s - loss: 0.0883 - acc: 0.9682 - val_loss: 0.0883 - val_acc: 0.9667
# Epoch 51/180
# F1 Macro Score: 0.93832
#  - 7s - loss: 0.0886 - acc: 0.9682 - val_loss: 0.0869 - val_acc: 0.9672
# Epoch 52/180
# F1 Macro Score: 0.93831
#  - 7s - loss: 0.0874 - acc: 0.9683 - val_loss: 0.0865 - val_acc: 0.9672
# Epoch 53/180
# F1 Macro Score: 0.93825
#  - 7s - loss: 0.0880 - acc: 0.9683 - val_loss: 0.0867 - val_acc: 0.9671
# Epoch 54/180
# F1 Macro Score: 0.93837
#  - 7s - loss: 0.0879 - acc: 0.9683 - val_loss: 0.0867 - val_acc: 0.9672
# Epoch 55/180
# F1 Macro Score: 0.93838
#  - 7s - loss: 0.0878 - acc: 0.9683 - val_loss: 0.0867 - val_acc: 0.9671
# Epoch 56/180
# F1 Macro Score: 0.93842
#  - 7s - loss: 0.0877 - acc: 0.9683 - val_loss: 0.0869 - val_acc: 0.9672
# Epoch 57/180
# F1 Macro Score: 0.93870
#  - 7s - loss: 0.0870 - acc: 0.9684 - val_loss: 0.0860 - val_acc: 0.9673
# Epoch 58/180
# F1 Macro Score: 0.93712
#  - 7s - loss: 0.0873 - acc: 0.9684 - val_loss: 0.0891 - val_acc: 0.9667
# Epoch 59/180
# F1 Macro Score: 0.93803
#  - 7s - loss: 0.0884 - acc: 0.9679 - val_loss: 0.0874 - val_acc: 0.9670
# Epoch 60/180
# F1 Macro Score: 0.93833
#  - 7s - loss: 0.0891 - acc: 0.9682 - val_loss: 0.0870 - val_acc: 0.9673
# Epoch 61/180
# F1 Macro Score: 0.93861
#  - 7s - loss: 0.0864 - acc: 0.9687 - val_loss: 0.0866 - val_acc: 0.9673
# Epoch 62/180
# F1 Macro Score: 0.93901
#  - 7s - loss: 0.0869 - acc: 0.9686 - val_loss: 0.0854 - val_acc: 0.9675
# Epoch 63/180
# F1 Macro Score: 0.93921
#  - 7s - loss: 0.0861 - acc: 0.9687 - val_loss: 0.0853 - val_acc: 0.9677
# Epoch 64/180
# F1 Macro Score: 0.93924
#  - 7s - loss: 0.0859 - acc: 0.9688 - val_loss: 0.0855 - val_acc: 0.9676
# Epoch 65/180
# F1 Macro Score: 0.93953
#  - 7s - loss: 0.0861 - acc: 0.9687 - val_loss: 0.0855 - val_acc: 0.9677
# Epoch 66/180
# F1 Macro Score: 0.93794
#  - 7s - loss: 0.0848 - acc: 0.9690 - val_loss: 0.0867 - val_acc: 0.9673
# Epoch 67/180
# F1 Macro Score: 0.93934
#  - 7s - loss: 0.0858 - acc: 0.9687 - val_loss: 0.0864 - val_acc: 0.9676
# Epoch 68/180
# F1 Macro Score: 0.93992
#  - 7s - loss: 0.0852 - acc: 0.9689 - val_loss: 0.0846 - val_acc: 0.9679
# Epoch 69/180
# F1 Macro Score: 0.93941
#  - 7s - loss: 0.0849 - acc: 0.9691 - val_loss: 0.0845 - val_acc: 0.9679
# Epoch 70/180
# F1 Macro Score: 0.94017
#  - 7s - loss: 0.0852 - acc: 0.9689 - val_loss: 0.0841 - val_acc: 0.9680
# Epoch 71/180
# F1 Macro Score: 0.93958
#  - 7s - loss: 0.0849 - acc: 0.9691 - val_loss: 0.0842 - val_acc: 0.9679
# Epoch 72/180
# F1 Macro Score: 0.93928
#  - 7s - loss: 0.0846 - acc: 0.9691 - val_loss: 0.0846 - val_acc: 0.9678
# Epoch 73/180
# F1 Macro Score: 0.93978
#  - 7s - loss: 0.0848 - acc: 0.9690 - val_loss: 0.0843 - val_acc: 0.9679
# Epoch 74/180
# F1 Macro Score: 0.94011
#  - 7s - loss: 0.0840 - acc: 0.9692 - val_loss: 0.0843 - val_acc: 0.9681
# Epoch 75/180
# F1 Macro Score: 0.94031
#  - 7s - loss: 0.0851 - acc: 0.9690 - val_loss: 0.0843 - val_acc: 0.9680
# Epoch 76/180
# F1 Macro Score: 0.94014
#  - 7s - loss: 0.0840 - acc: 0.9692 - val_loss: 0.0841 - val_acc: 0.9680
# Epoch 77/180
# F1 Macro Score: 0.93946
#  - 7s - loss: 0.0844 - acc: 0.9691 - val_loss: 0.0849 - val_acc: 0.9679
# Epoch 78/180
# F1 Macro Score: 0.93975
#  - 7s - loss: 0.0838 - acc: 0.9692 - val_loss: 0.0840 - val_acc: 0.9680
# Epoch 79/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0840 - acc: 0.9692 - val_loss: 0.0834 - val_acc: 0.9683
# Epoch 80/180
# F1 Macro Score: 0.93977
#  - 7s - loss: 0.0832 - acc: 0.9694 - val_loss: 0.0849 - val_acc: 0.9678
# Epoch 81/180
# F1 Macro Score: 0.94047
#  - 7s - loss: 0.0831 - acc: 0.9694 - val_loss: 0.0834 - val_acc: 0.9682
# Epoch 82/180
# F1 Macro Score: 0.94040
#  - 7s - loss: 0.0839 - acc: 0.9693 - val_loss: 0.0836 - val_acc: 0.9682
# Epoch 83/180
# F1 Macro Score: 0.94052
#  - 7s - loss: 0.0832 - acc: 0.9694 - val_loss: 0.0833 - val_acc: 0.9682
# Epoch 84/180
# F1 Macro Score: 0.94013
#  - 7s - loss: 0.0837 - acc: 0.9694 - val_loss: 0.0841 - val_acc: 0.9680
# Epoch 85/180
# F1 Macro Score: 0.94023
#  - 7s - loss: 0.0834 - acc: 0.9694 - val_loss: 0.0836 - val_acc: 0.9682
# Epoch 86/180
# F1 Macro Score: 0.94034
#  - 7s - loss: 0.0833 - acc: 0.9694 - val_loss: 0.0835 - val_acc: 0.9681
# Epoch 87/180
# F1 Macro Score: 0.94029
#  - 7s - loss: 0.0838 - acc: 0.9693 - val_loss: 0.0834 - val_acc: 0.9682
# Epoch 88/180
# F1 Macro Score: 0.94028
#  - 7s - loss: 0.0833 - acc: 0.9694 - val_loss: 0.0833 - val_acc: 0.9682
# Epoch 89/180
# F1 Macro Score: 0.94037
#  - 7s - loss: 0.0828 - acc: 0.9694 - val_loss: 0.0839 - val_acc: 0.9682
# Epoch 90/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0830 - acc: 0.9694 - val_loss: 0.0832 - val_acc: 0.9684
# Epoch 91/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0825 - acc: 0.9696 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 92/180
# F1 Macro Score: 0.94061
#  - 7s - loss: 0.0822 - acc: 0.9697 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 93/180
# F1 Macro Score: 0.94061
#  - 7s - loss: 0.0821 - acc: 0.9697 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 94/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0826 - acc: 0.9696 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 95/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 96/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0829 - val_acc: 0.9684
# Epoch 97/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 98/180
# F1 Macro Score: 0.94053
#  - 7s - loss: 0.0824 - acc: 0.9695 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 99/180
# F1 Macro Score: 0.94084
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9685
# Epoch 100/180
# F1 Macro Score: 0.94080
#  - 7s - loss: 0.0824 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9685
# Epoch 101/180
# F1 Macro Score: 0.94061
#  - 7s - loss: 0.0823 - acc: 0.9697 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 102/180
# F1 Macro Score: 0.94050
#  - 7s - loss: 0.0824 - acc: 0.9697 - val_loss: 0.0829 - val_acc: 0.9684
# Epoch 103/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0825 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9685
# Epoch 104/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0820 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 105/180
# F1 Macro Score: 0.94040
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0828 - val_acc: 0.9683
# Epoch 106/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0823 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 107/180
# F1 Macro Score: 0.94057
#  - 7s - loss: 0.0820 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 108/180
# F1 Macro Score: 0.94048
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 109/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 110/180
# F1 Macro Score: 0.94067
#  - 7s - loss: 0.0821 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 111/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0822 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 112/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0821 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 113/180
# F1 Macro Score: 0.94052
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 114/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0820 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 115/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0823 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 116/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 117/180
# F1 Macro Score: 0.94048
#  - 7s - loss: 0.0820 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 118/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 119/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0823 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 120/180
# F1 Macro Score: 0.94049
#  - 7s - loss: 0.0812 - acc: 0.9698 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 121/180
# F1 Macro Score: 0.94052
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 122/180
# F1 Macro Score: 0.94032
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0829 - val_acc: 0.9683
# Epoch 123/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0824 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 124/180
# F1 Macro Score: 0.94083
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 125/180
# F1 Macro Score: 0.94083
#  - 7s - loss: 0.0820 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 126/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 127/180
# F1 Macro Score: 0.94086
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 128/180
# F1 Macro Score: 0.94040
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 129/180
# F1 Macro Score: 0.94089
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 130/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 131/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 132/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 133/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 134/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 135/180
# F1 Macro Score: 0.94046
#  - 7s - loss: 0.0821 - acc: 0.9697 - val_loss: 0.0828 - val_acc: 0.9684
# Epoch 136/180
# F1 Macro Score: 0.94086
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9685
# Epoch 137/180
# F1 Macro Score: 0.94022
#  - 7s - loss: 0.0816 - acc: 0.9698 - val_loss: 0.0830 - val_acc: 0.9683
# Epoch 138/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 139/180
# F1 Macro Score: 0.94056
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 140/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0814 - acc: 0.9699 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 141/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 142/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 143/180
# F1 Macro Score: 0.94082
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 144/180
# F1 Macro Score: 0.94055
#  - 7s - loss: 0.0816 - acc: 0.9697 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 145/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 146/180
# F1 Macro Score: 0.94046
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 147/180
# F1 Macro Score: 0.94087
#  - 7s - loss: 0.0815 - acc: 0.9697 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 148/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 149/180
# F1 Macro Score: 0.94094
#  - 7s - loss: 0.0819 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 150/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 151/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 152/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 153/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 154/180
# F1 Macro Score: 0.94090
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 155/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 156/180
# F1 Macro Score: 0.94093
#  - 7s - loss: 0.0815 - acc: 0.9697 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 157/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0817 - acc: 0.9697 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 158/180
# F1 Macro Score: 0.94044
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 159/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9684
# Epoch 160/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 161/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0813 - acc: 0.9699 - val_loss: 0.0824 - val_acc: 0.9684
# Epoch 162/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0818 - acc: 0.9697 - val_loss: 0.0824 - val_acc: 0.9684
# Epoch 163/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0814 - acc: 0.9699 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 164/180
# F1 Macro Score: 0.94048
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0827 - val_acc: 0.9684
# Epoch 165/180
# F1 Macro Score: 0.94086
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 166/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0812 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9684
# Epoch 167/180
# F1 Macro Score: 0.94079
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 168/180
# F1 Macro Score: 0.94082
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 169/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0812 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 170/180
# F1 Macro Score: 0.94083
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 171/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0822 - acc: 0.9696 - val_loss: 0.0826 - val_acc: 0.9684
# Epoch 172/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0810 - acc: 0.9699 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 173/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0812 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9684
# Epoch 174/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 175/180
# F1 Macro Score: 0.94085
#  - 7s - loss: 0.0814 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 176/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0811 - acc: 0.9699 - val_loss: 0.0824 - val_acc: 0.9685
# Epoch 177/180
# F1 Macro Score: 0.94088
#  - 7s - loss: 0.0812 - acc: 0.9698 - val_loss: 0.0825 - val_acc: 0.9685
# Epoch 178/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0813 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9684
# Epoch 179/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0811 - acc: 0.9699 - val_loss: 0.0823 - val_acc: 0.9685
# Epoch 180/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0815 - acc: 0.9698 - val_loss: 0.0824 - val_acc: 0.9685
# Training fold 1 completed. macro f1 score : 0.94077
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.72669
#  - 18s - loss: 0.5081 - acc: 0.8626 - val_loss: 0.9114 - val_acc: 0.9133
# Epoch 2/180
# F1 Macro Score: 0.86938
#  - 7s - loss: 0.1856 - acc: 0.9578 - val_loss: 0.4372 - val_acc: 0.9608
# Epoch 3/180
# F1 Macro Score: 0.92499
#  - 7s - loss: 0.1447 - acc: 0.9639 - val_loss: 0.2029 - val_acc: 0.9665
# Epoch 4/180
# F1 Macro Score: 0.92920
#  - 7s - loss: 0.1306 - acc: 0.9652 - val_loss: 0.1499 - val_acc: 0.9674
# Epoch 5/180
# F1 Macro Score: 0.93329
#  - 7s - loss: 0.1271 - acc: 0.9654 - val_loss: 0.1206 - val_acc: 0.9682
# Epoch 6/180
# F1 Macro Score: 0.93167
#  - 7s - loss: 0.1194 - acc: 0.9660 - val_loss: 0.1177 - val_acc: 0.9663
# Epoch 7/180
# F1 Macro Score: 0.93626
#  - 7s - loss: 0.1157 - acc: 0.9661 - val_loss: 0.0992 - val_acc: 0.9689
# Epoch 8/180
# F1 Macro Score: 0.93746
#  - 7s - loss: 0.1164 - acc: 0.9659 - val_loss: 0.0999 - val_acc: 0.9687
# Epoch 9/180
# F1 Macro Score: 0.93576
#  - 7s - loss: 0.1109 - acc: 0.9663 - val_loss: 0.1026 - val_acc: 0.9677
# Epoch 10/180
# F1 Macro Score: 0.93753
#  - 7s - loss: 0.1110 - acc: 0.9662 - val_loss: 0.1001 - val_acc: 0.9686
# Epoch 11/180
# F1 Macro Score: 0.93812
#  - 7s - loss: 0.1081 - acc: 0.9663 - val_loss: 0.0939 - val_acc: 0.9689
# Epoch 12/180
# F1 Macro Score: 0.93926
#  - 7s - loss: 0.1057 - acc: 0.9665 - val_loss: 0.0919 - val_acc: 0.9693
# Epoch 13/180
# F1 Macro Score: 0.93306
#  - 7s - loss: 0.1046 - acc: 0.9664 - val_loss: 0.0993 - val_acc: 0.9670
# Epoch 14/180
# F1 Macro Score: 0.93925
#  - 7s - loss: 0.1056 - acc: 0.9663 - val_loss: 0.0892 - val_acc: 0.9694
# Epoch 15/180
# F1 Macro Score: 0.93744
#  - 7s - loss: 0.1019 - acc: 0.9666 - val_loss: 0.0929 - val_acc: 0.9686
# Epoch 16/180
# F1 Macro Score: 0.93469
#  - 7s - loss: 0.1028 - acc: 0.9664 - val_loss: 0.0959 - val_acc: 0.9678
# Epoch 17/180
# F1 Macro Score: 0.93841
#  - 7s - loss: 0.1016 - acc: 0.9664 - val_loss: 0.0882 - val_acc: 0.9694
# Epoch 18/180
# F1 Macro Score: 0.93665
#  - 7s - loss: 0.0998 - acc: 0.9667 - val_loss: 0.0922 - val_acc: 0.9681
# Epoch 19/180
# F1 Macro Score: 0.92525
#  - 7s - loss: 0.0995 - acc: 0.9665 - val_loss: 0.1059 - val_acc: 0.9636
# Epoch 20/180
# F1 Macro Score: 0.92547
#  - 7s - loss: 0.1006 - acc: 0.9664 - val_loss: 0.1098 - val_acc: 0.9637
# Epoch 21/180
# F1 Macro Score: 0.93765
#  - 7s - loss: 0.0993 - acc: 0.9667 - val_loss: 0.0927 - val_acc: 0.9685
# Epoch 22/180
# F1 Macro Score: 0.93829
#  - 7s - loss: 0.1014 - acc: 0.9664 - val_loss: 0.0910 - val_acc: 0.9688
# Epoch 23/180
# F1 Macro Score: 0.93885
#  - 7s - loss: 0.0967 - acc: 0.9669 - val_loss: 0.0852 - val_acc: 0.9694
# Epoch 24/180
# F1 Macro Score: 0.93930
#  - 7s - loss: 0.0951 - acc: 0.9669 - val_loss: 0.0856 - val_acc: 0.9695
# Epoch 25/180
# F1 Macro Score: 0.93841
#  - 7s - loss: 0.0965 - acc: 0.9669 - val_loss: 0.0856 - val_acc: 0.9692
# Epoch 26/180
# F1 Macro Score: 0.93829
#  - 7s - loss: 0.0946 - acc: 0.9670 - val_loss: 0.0887 - val_acc: 0.9689
# Epoch 27/180
# F1 Macro Score: 0.93838
#  - 7s - loss: 0.0940 - acc: 0.9670 - val_loss: 0.0844 - val_acc: 0.9694
# Epoch 28/180
# F1 Macro Score: 0.93817
#  - 7s - loss: 0.0934 - acc: 0.9672 - val_loss: 0.0866 - val_acc: 0.9690
# Epoch 29/180
# F1 Macro Score: 0.94010
#  - 7s - loss: 0.0946 - acc: 0.9669 - val_loss: 0.0823 - val_acc: 0.9699
# Epoch 30/180
# F1 Macro Score: 0.93909
#  - 7s - loss: 0.0949 - acc: 0.9670 - val_loss: 0.0862 - val_acc: 0.9693
# Epoch 31/180
# F1 Macro Score: 0.93916
#  - 7s - loss: 0.0916 - acc: 0.9675 - val_loss: 0.0828 - val_acc: 0.9697
# Epoch 32/180
# F1 Macro Score: 0.94023
#  - 7s - loss: 0.0896 - acc: 0.9677 - val_loss: 0.0809 - val_acc: 0.9701
# Epoch 33/180
# F1 Macro Score: 0.93894
#  - 7s - loss: 0.0895 - acc: 0.9678 - val_loss: 0.0827 - val_acc: 0.9696
# Epoch 34/180
# F1 Macro Score: 0.93992
#  - 7s - loss: 0.0936 - acc: 0.9672 - val_loss: 0.0827 - val_acc: 0.9698
# Epoch 35/180
# F1 Macro Score: 0.93880
#  - 7s - loss: 0.0896 - acc: 0.9677 - val_loss: 0.0827 - val_acc: 0.9695
# Epoch 36/180
# F1 Macro Score: 0.93991
#  - 7s - loss: 0.0889 - acc: 0.9678 - val_loss: 0.0813 - val_acc: 0.9699
# Epoch 37/180
# F1 Macro Score: 0.93836
#  - 7s - loss: 0.0889 - acc: 0.9678 - val_loss: 0.0837 - val_acc: 0.9692
# Epoch 38/180
# F1 Macro Score: 0.93956
#  - 7s - loss: 0.0888 - acc: 0.9679 - val_loss: 0.0810 - val_acc: 0.9699
# Epoch 39/180
# F1 Macro Score: 0.93791
#  - 7s - loss: 0.0873 - acc: 0.9681 - val_loss: 0.0847 - val_acc: 0.9690
# Epoch 40/180
# F1 Macro Score: 0.93948
#  - 7s - loss: 0.0886 - acc: 0.9678 - val_loss: 0.0809 - val_acc: 0.9699
# Epoch 41/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0875 - acc: 0.9681 - val_loss: 0.0795 - val_acc: 0.9703
# Epoch 42/180
# F1 Macro Score: 0.94012
#  - 7s - loss: 0.0865 - acc: 0.9683 - val_loss: 0.0805 - val_acc: 0.9701
# Epoch 43/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0864 - acc: 0.9683 - val_loss: 0.0793 - val_acc: 0.9704
# Epoch 44/180
# F1 Macro Score: 0.94044
#  - 7s - loss: 0.0863 - acc: 0.9683 - val_loss: 0.0797 - val_acc: 0.9702
# Epoch 45/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0866 - acc: 0.9683 - val_loss: 0.0795 - val_acc: 0.9703
# Epoch 46/180
# F1 Macro Score: 0.94010
#  - 7s - loss: 0.0863 - acc: 0.9683 - val_loss: 0.0804 - val_acc: 0.9700
# Epoch 47/180
# F1 Macro Score: 0.94051
#  - 7s - loss: 0.0857 - acc: 0.9685 - val_loss: 0.0791 - val_acc: 0.9704
# Epoch 48/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0857 - acc: 0.9684 - val_loss: 0.0794 - val_acc: 0.9703
# Epoch 49/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0854 - acc: 0.9685 - val_loss: 0.0790 - val_acc: 0.9704
# Epoch 50/180
# F1 Macro Score: 0.94044
#  - 7s - loss: 0.0857 - acc: 0.9685 - val_loss: 0.0793 - val_acc: 0.9702
# Epoch 51/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0850 - acc: 0.9686 - val_loss: 0.0795 - val_acc: 0.9703
# Epoch 52/180
# F1 Macro Score: 0.94044
#  - 7s - loss: 0.0847 - acc: 0.9687 - val_loss: 0.0792 - val_acc: 0.9703
# Epoch 53/180
# F1 Macro Score: 0.94050
#  - 7s - loss: 0.0842 - acc: 0.9688 - val_loss: 0.0791 - val_acc: 0.9703
# Epoch 54/180
# F1 Macro Score: 0.94101
#  - 7s - loss: 0.0847 - acc: 0.9687 - val_loss: 0.0787 - val_acc: 0.9704
# Epoch 55/180
# F1 Macro Score: 0.93995
#  - 7s - loss: 0.0848 - acc: 0.9687 - val_loss: 0.0804 - val_acc: 0.9700
# Epoch 56/180
# F1 Macro Score: 0.94082
#  - 7s - loss: 0.0851 - acc: 0.9685 - val_loss: 0.0790 - val_acc: 0.9705
# Epoch 57/180
# F1 Macro Score: 0.94040
#  - 7s - loss: 0.0841 - acc: 0.9687 - val_loss: 0.0792 - val_acc: 0.9702
# Epoch 58/180
# F1 Macro Score: 0.94098
#  - 7s - loss: 0.0843 - acc: 0.9688 - val_loss: 0.0784 - val_acc: 0.9705
# Epoch 59/180
# F1 Macro Score: 0.94085
#  - 7s - loss: 0.0844 - acc: 0.9688 - val_loss: 0.0787 - val_acc: 0.9704
# Epoch 60/180
# F1 Macro Score: 0.94067
#  - 7s - loss: 0.0846 - acc: 0.9688 - val_loss: 0.0788 - val_acc: 0.9704
# Epoch 61/180
# F1 Macro Score: 0.94053
#  - 7s - loss: 0.0836 - acc: 0.9689 - val_loss: 0.0787 - val_acc: 0.9703
# Epoch 62/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0832 - acc: 0.9691 - val_loss: 0.0784 - val_acc: 0.9705
# Epoch 63/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0834 - acc: 0.9689 - val_loss: 0.0785 - val_acc: 0.9705
# Epoch 64/180
# F1 Macro Score: 0.94101
#  - 7s - loss: 0.0834 - acc: 0.9690 - val_loss: 0.0783 - val_acc: 0.9705
# Epoch 65/180
# F1 Macro Score: 0.94020
#  - 7s - loss: 0.0833 - acc: 0.9690 - val_loss: 0.0789 - val_acc: 0.9702
# Epoch 66/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0833 - acc: 0.9690 - val_loss: 0.0782 - val_acc: 0.9706
# Epoch 67/180
# F1 Macro Score: 0.94056
#  - 7s - loss: 0.0833 - acc: 0.9690 - val_loss: 0.0789 - val_acc: 0.9703
# Epoch 68/180
# F1 Macro Score: 0.94095
#  - 7s - loss: 0.0837 - acc: 0.9689 - val_loss: 0.0786 - val_acc: 0.9705
# Epoch 69/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0830 - acc: 0.9691 - val_loss: 0.0784 - val_acc: 0.9704
# Epoch 70/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0830 - acc: 0.9691 - val_loss: 0.0787 - val_acc: 0.9704
# Epoch 71/180
# F1 Macro Score: 0.94041
#  - 7s - loss: 0.0827 - acc: 0.9692 - val_loss: 0.0791 - val_acc: 0.9702
# Epoch 72/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0828 - acc: 0.9692 - val_loss: 0.0784 - val_acc: 0.9704
# Epoch 73/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0822 - acc: 0.9693 - val_loss: 0.0786 - val_acc: 0.9704
# Epoch 74/180
# F1 Macro Score: 0.94032
#  - 7s - loss: 0.0828 - acc: 0.9691 - val_loss: 0.0790 - val_acc: 0.9703
# Epoch 75/180
# F1 Macro Score: 0.94007
#  - 7s - loss: 0.0825 - acc: 0.9692 - val_loss: 0.0788 - val_acc: 0.9702
# Epoch 76/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0822 - acc: 0.9693 - val_loss: 0.0782 - val_acc: 0.9705
# Epoch 77/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0824 - acc: 0.9692 - val_loss: 0.0785 - val_acc: 0.9703
# Epoch 78/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0826 - acc: 0.9692 - val_loss: 0.0785 - val_acc: 0.9704
# Epoch 79/180
# F1 Macro Score: 0.94098
#  - 7s - loss: 0.0820 - acc: 0.9693 - val_loss: 0.0781 - val_acc: 0.9705
# Epoch 80/180
# F1 Macro Score: 0.94049
#  - 7s - loss: 0.0823 - acc: 0.9693 - val_loss: 0.0786 - val_acc: 0.9703
# Epoch 81/180
# F1 Macro Score: 0.94091
#  - 7s - loss: 0.0820 - acc: 0.9694 - val_loss: 0.0783 - val_acc: 0.9705
# Epoch 82/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0816 - acc: 0.9694 - val_loss: 0.0784 - val_acc: 0.9704
# Epoch 83/180
# F1 Macro Score: 0.94095
#  - 7s - loss: 0.0814 - acc: 0.9695 - val_loss: 0.0781 - val_acc: 0.9705
# Epoch 84/180
# F1 Macro Score: 0.94028
#  - 7s - loss: 0.0820 - acc: 0.9694 - val_loss: 0.0787 - val_acc: 0.9703
# Epoch 85/180
# F1 Macro Score: 0.94110
#  - 7s - loss: 0.0816 - acc: 0.9694 - val_loss: 0.0781 - val_acc: 0.9705
# Epoch 86/180
# F1 Macro Score: 0.94085
#  - 7s - loss: 0.0824 - acc: 0.9693 - val_loss: 0.0784 - val_acc: 0.9704
# Epoch 87/180
# F1 Macro Score: 0.94047
#  - 7s - loss: 0.0817 - acc: 0.9694 - val_loss: 0.0782 - val_acc: 0.9704
# Epoch 88/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0812 - acc: 0.9695 - val_loss: 0.0782 - val_acc: 0.9704
# Epoch 89/180
# F1 Macro Score: 0.94105
#  - 7s - loss: 0.0814 - acc: 0.9696 - val_loss: 0.0781 - val_acc: 0.9705
# Epoch 90/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0812 - acc: 0.9695 - val_loss: 0.0781 - val_acc: 0.9704
# Epoch 91/180
# F1 Macro Score: 0.94098
#  - 7s - loss: 0.0808 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 92/180
# F1 Macro Score: 0.94115
#  - 7s - loss: 0.0807 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 93/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0806 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 94/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0809 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 95/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0807 - acc: 0.9696 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 96/180
# F1 Macro Score: 0.94118
#  - 7s - loss: 0.0805 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 97/180
# F1 Macro Score: 0.94127
#  - 9s - loss: 0.0803 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 98/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0801 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 99/180
# F1 Macro Score: 0.94091
#  - 7s - loss: 0.0804 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 100/180
# F1 Macro Score: 0.94103
#  - 7s - loss: 0.0804 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 101/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0806 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 102/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0805 - acc: 0.9697 - val_loss: 0.0778 - val_acc: 0.9706
# Epoch 103/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0808 - acc: 0.9697 - val_loss: 0.0780 - val_acc: 0.9704
# Epoch 104/180
# F1 Macro Score: 0.94103
#  - 7s - loss: 0.0801 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 105/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0802 - acc: 0.9697 - val_loss: 0.0778 - val_acc: 0.9706
# Epoch 106/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0802 - acc: 0.9698 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 107/180
# F1 Macro Score: 0.94100
#  - 7s - loss: 0.0802 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 108/180
# F1 Macro Score: 0.94114
#  - 7s - loss: 0.0806 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 109/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0801 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 110/180
# F1 Macro Score: 0.94094
#  - 7s - loss: 0.0806 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 111/180
# F1 Macro Score: 0.94121
#  - 7s - loss: 0.0801 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 112/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0806 - acc: 0.9697 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 113/180
# F1 Macro Score: 0.94115
#  - 7s - loss: 0.0809 - acc: 0.9696 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 114/180
# F1 Macro Score: 0.94124
#  - 7s - loss: 0.0801 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 115/180
# F1 Macro Score: 0.94094
#  - 7s - loss: 0.0807 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 116/180
# F1 Macro Score: 0.94080
#  - 7s - loss: 0.0803 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 117/180
# F1 Macro Score: 0.94100
#  - 7s - loss: 0.0805 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 118/180
# F1 Macro Score: 0.94104
#  - 7s - loss: 0.0802 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 119/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0804 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 120/180
# F1 Macro Score: 0.94113
#  - 7s - loss: 0.0799 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 121/180
# F1 Macro Score: 0.94127
#  - 7s - loss: 0.0801 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 122/180
# F1 Macro Score: 0.94121
#  - 7s - loss: 0.0802 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 123/180
# F1 Macro Score: 0.94113
#  - 7s - loss: 0.0805 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 124/180
# F1 Macro Score: 0.94113
#  - 7s - loss: 0.0804 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 125/180
# F1 Macro Score: 0.94120
#  - 7s - loss: 0.0803 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 126/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0805 - acc: 0.9697 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 127/180
# F1 Macro Score: 0.94104
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 128/180
# F1 Macro Score: 0.94110
#  - 7s - loss: 0.0800 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 129/180
# F1 Macro Score: 0.94096
#  - 7s - loss: 0.0800 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 130/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0802 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 131/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0803 - acc: 0.9698 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 132/180
# F1 Macro Score: 0.94108
#  - 7s - loss: 0.0806 - acc: 0.9697 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 133/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 134/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0802 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 135/180
# F1 Macro Score: 0.94127
#  - 7s - loss: 0.0800 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 136/180
# F1 Macro Score: 0.94105
#  - 7s - loss: 0.0798 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 137/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0800 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 138/180
# F1 Macro Score: 0.94121
#  - 7s - loss: 0.0799 - acc: 0.9698 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 139/180
# F1 Macro Score: 0.94124
#  - 7s - loss: 0.0800 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 140/180
# F1 Macro Score: 0.94067
#  - 7s - loss: 0.0803 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9704
# Epoch 141/180
# F1 Macro Score: 0.94120
#  - 7s - loss: 0.0801 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 142/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0798 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 143/180
# F1 Macro Score: 0.94112
#  - 7s - loss: 0.0799 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 144/180
# F1 Macro Score: 0.94108
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 145/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 146/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 147/180
# F1 Macro Score: 0.94110
#  - 7s - loss: 0.0796 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 148/180
# F1 Macro Score: 0.94119
#  - 7s - loss: 0.0802 - acc: 0.9698 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 149/180
# F1 Macro Score: 0.94114
#  - 7s - loss: 0.0797 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 150/180
# F1 Macro Score: 0.94108
#  - 7s - loss: 0.0801 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 151/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0799 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 152/180
# F1 Macro Score: 0.94119
#  - 7s - loss: 0.0800 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 153/180
# F1 Macro Score: 0.94099
#  - 7s - loss: 0.0801 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 154/180
# F1 Macro Score: 0.94123
#  - 7s - loss: 0.0798 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 155/180
# F1 Macro Score: 0.94098
#  - 7s - loss: 0.0797 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 156/180
# F1 Macro Score: 0.94100
#  - 7s - loss: 0.0797 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 157/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0798 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 158/180
# F1 Macro Score: 0.94102
#  - 7s - loss: 0.0800 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 159/180
# F1 Macro Score: 0.94083
#  - 7s - loss: 0.0798 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 160/180
# F1 Macro Score: 0.94097
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 161/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0797 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 162/180
# F1 Macro Score: 0.94083
#  - 7s - loss: 0.0796 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 163/180
# F1 Macro Score: 0.94116
#  - 7s - loss: 0.0798 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 164/180
# F1 Macro Score: 0.94107
#  - 7s - loss: 0.0796 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 165/180
# F1 Macro Score: 0.94096
#  - 7s - loss: 0.0800 - acc: 0.9698 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 166/180
# F1 Macro Score: 0.94085
#  - 7s - loss: 0.0798 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 167/180
# F1 Macro Score: 0.94101
#  - 7s - loss: 0.0799 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 168/180
# F1 Macro Score: 0.94114
#  - 7s - loss: 0.0801 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 169/180
# F1 Macro Score: 0.94096
#  - 7s - loss: 0.0794 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 170/180
# F1 Macro Score: 0.94118
#  - 7s - loss: 0.0800 - acc: 0.9698 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 171/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0797 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9706
# Epoch 172/180
# F1 Macro Score: 0.94126
#  - 7s - loss: 0.0795 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 173/180
# F1 Macro Score: 0.94106
#  - 7s - loss: 0.0798 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 174/180
# F1 Macro Score: 0.94111
#  - 7s - loss: 0.0798 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 175/180
# F1 Macro Score: 0.94117
#  - 7s - loss: 0.0795 - acc: 0.9699 - val_loss: 0.0780 - val_acc: 0.9706
# Epoch 176/180
# F1 Macro Score: 0.94108
#  - 7s - loss: 0.0796 - acc: 0.9699 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 177/180
# F1 Macro Score: 0.94101
#  - 7s - loss: 0.0796 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9705
# Epoch 178/180
# F1 Macro Score: 0.94100
#  - 7s - loss: 0.0797 - acc: 0.9700 - val_loss: 0.0780 - val_acc: 0.9705
# Epoch 179/180
# F1 Macro Score: 0.94122
#  - 7s - loss: 0.0796 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9706
# Epoch 180/180
# F1 Macro Score: 0.94121
#  - 7s - loss: 0.0793 - acc: 0.9700 - val_loss: 0.0779 - val_acc: 0.9706
# Training fold 2 completed. macro f1 score : 0.94121
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.68199
#  - 19s - loss: 0.5305 - acc: 0.8476 - val_loss: 0.9257 - val_acc: 0.8955
# Epoch 2/180
# F1 Macro Score: 0.79636
#  - 7s - loss: 0.1747 - acc: 0.9593 - val_loss: 0.5210 - val_acc: 0.9358
# Epoch 3/180
# F1 Macro Score: 0.92157
#  - 7s - loss: 0.1475 - acc: 0.9637 - val_loss: 0.2468 - val_acc: 0.9646
# Epoch 4/180
# F1 Macro Score: 0.93316
#  - 7s - loss: 0.1304 - acc: 0.9654 - val_loss: 0.1437 - val_acc: 0.9670
# Epoch 5/180
# F1 Macro Score: 0.93410
#  - 7s - loss: 0.1222 - acc: 0.9660 - val_loss: 0.1156 - val_acc: 0.9672
# Epoch 6/180
# F1 Macro Score: 0.93595
#  - 7s - loss: 0.1203 - acc: 0.9660 - val_loss: 0.1052 - val_acc: 0.9676
# Epoch 7/180
# F1 Macro Score: 0.93614
#  - 7s - loss: 0.1196 - acc: 0.9659 - val_loss: 0.1062 - val_acc: 0.9678
# Epoch 8/180
# F1 Macro Score: 0.93442
#  - 7s - loss: 0.1145 - acc: 0.9663 - val_loss: 0.1029 - val_acc: 0.9673
# Epoch 9/180
# F1 Macro Score: 0.93482
#  - 7s - loss: 0.1124 - acc: 0.9663 - val_loss: 0.0977 - val_acc: 0.9680
# Epoch 10/180
# F1 Macro Score: 0.93036
#  - 7s - loss: 0.1102 - acc: 0.9663 - val_loss: 0.1088 - val_acc: 0.9658
# Epoch 11/180
# F1 Macro Score: 0.93482
#  - 7s - loss: 0.1092 - acc: 0.9664 - val_loss: 0.0999 - val_acc: 0.9673
# Epoch 12/180
# F1 Macro Score: 0.93629
#  - 7s - loss: 0.1070 - acc: 0.9665 - val_loss: 0.0945 - val_acc: 0.9680
# Epoch 13/180
# F1 Macro Score: 0.93529
#  - 7s - loss: 0.1058 - acc: 0.9665 - val_loss: 0.0952 - val_acc: 0.9677
# Epoch 14/180
# F1 Macro Score: 0.93702
#  - 7s - loss: 0.1029 - acc: 0.9667 - val_loss: 0.0912 - val_acc: 0.9684
# Epoch 15/180
# F1 Macro Score: 0.93205
#  - 7s - loss: 0.1034 - acc: 0.9664 - val_loss: 0.0981 - val_acc: 0.9670
# Epoch 16/180
# F1 Macro Score: 0.93218
#  - 7s - loss: 0.1044 - acc: 0.9664 - val_loss: 0.1025 - val_acc: 0.9661
# Epoch 17/180
# F1 Macro Score: 0.93385
#  - 7s - loss: 0.1031 - acc: 0.9665 - val_loss: 0.0999 - val_acc: 0.9668
# Epoch 18/180
# F1 Macro Score: 0.93339
#  - 7s - loss: 0.1017 - acc: 0.9666 - val_loss: 0.0931 - val_acc: 0.9676
# Epoch 19/180
# F1 Macro Score: 0.93544
#  - 7s - loss: 0.1003 - acc: 0.9667 - val_loss: 0.0922 - val_acc: 0.9679
# Epoch 20/180
# F1 Macro Score: 0.93402
#  - 7s - loss: 0.1019 - acc: 0.9664 - val_loss: 0.0941 - val_acc: 0.9675
# Epoch 21/180
# F1 Macro Score: 0.93545
#  - 7s - loss: 0.1028 - acc: 0.9665 - val_loss: 0.0942 - val_acc: 0.9677
# Epoch 22/180
# F1 Macro Score: 0.93577
#  - 7s - loss: 0.1015 - acc: 0.9665 - val_loss: 0.0904 - val_acc: 0.9681
# Epoch 23/180
# F1 Macro Score: 0.92871
#  - 7s - loss: 0.0994 - acc: 0.9666 - val_loss: 0.0977 - val_acc: 0.9665
# Epoch 24/180
# F1 Macro Score: 0.92881
#  - 7s - loss: 0.0981 - acc: 0.9668 - val_loss: 0.0963 - val_acc: 0.9663
# Epoch 25/180
# F1 Macro Score: 0.93593
#  - 7s - loss: 0.0971 - acc: 0.9668 - val_loss: 0.0902 - val_acc: 0.9681
# Epoch 26/180
# F1 Macro Score: 0.93553
#  - 7s - loss: 0.0976 - acc: 0.9668 - val_loss: 0.0914 - val_acc: 0.9677
# Epoch 27/180
# F1 Macro Score: 0.93694
#  - 7s - loss: 0.0955 - acc: 0.9670 - val_loss: 0.0863 - val_acc: 0.9685
# Epoch 28/180
# F1 Macro Score: 0.93503
#  - 7s - loss: 0.0945 - acc: 0.9670 - val_loss: 0.0895 - val_acc: 0.9676
# Epoch 29/180
# F1 Macro Score: 0.93669
#  - 7s - loss: 0.0940 - acc: 0.9672 - val_loss: 0.0875 - val_acc: 0.9684
# Epoch 30/180
# F1 Macro Score: 0.59750
#  - 7s - loss: 0.2413 - acc: 0.9249 - val_loss: 1.2221 - val_acc: 0.8576
# Epoch 31/180
# F1 Macro Score: 0.92424
#  - 7s - loss: 0.1395 - acc: 0.9613 - val_loss: 0.1473 - val_acc: 0.9622
# Epoch 32/180
# F1 Macro Score: 0.93459
#  - 7s - loss: 0.1232 - acc: 0.9648 - val_loss: 0.1136 - val_acc: 0.9668
# Epoch 33/180
# F1 Macro Score: 0.93617
#  - 7s - loss: 0.1153 - acc: 0.9659 - val_loss: 0.1012 - val_acc: 0.9678
# Epoch 34/180
# F1 Macro Score: 0.93650
#  - 7s - loss: 0.1152 - acc: 0.9657 - val_loss: 0.0988 - val_acc: 0.9679
# Epoch 35/180
# F1 Macro Score: 0.93637
#  - 7s - loss: 0.1112 - acc: 0.9662 - val_loss: 0.0974 - val_acc: 0.9679
# Epoch 36/180
# F1 Macro Score: 0.93654
#  - 7s - loss: 0.1092 - acc: 0.9664 - val_loss: 0.0964 - val_acc: 0.9680
# Epoch 37/180
# F1 Macro Score: 0.93609
#  - 7s - loss: 0.1085 - acc: 0.9662 - val_loss: 0.0968 - val_acc: 0.9679
# Epoch 38/180
# F1 Macro Score: 0.93629
#  - 7s - loss: 0.1072 - acc: 0.9664 - val_loss: 0.0954 - val_acc: 0.9679
# Epoch 39/180
# F1 Macro Score: 0.93652
#  - 7s - loss: 0.1061 - acc: 0.9664 - val_loss: 0.0936 - val_acc: 0.9680
# Epoch 40/180
# F1 Macro Score: 0.93641
#  - 7s - loss: 0.1054 - acc: 0.9665 - val_loss: 0.0940 - val_acc: 0.9680
# Epoch 41/180
# F1 Macro Score: 0.93688
#  - 7s - loss: 0.1034 - acc: 0.9667 - val_loss: 0.0921 - val_acc: 0.9682
# Epoch 42/180
# F1 Macro Score: 0.93656
#  - 7s - loss: 0.1019 - acc: 0.9669 - val_loss: 0.0919 - val_acc: 0.9682
# Epoch 43/180
# F1 Macro Score: 0.93674
#  - 7s - loss: 0.1022 - acc: 0.9668 - val_loss: 0.0919 - val_acc: 0.9681
# Epoch 44/180
# F1 Macro Score: 0.93679
#  - 7s - loss: 0.1018 - acc: 0.9668 - val_loss: 0.0910 - val_acc: 0.9683
# Epoch 45/180
# F1 Macro Score: 0.93700
#  - 7s - loss: 0.1017 - acc: 0.9668 - val_loss: 0.0908 - val_acc: 0.9683
# Epoch 46/180
# F1 Macro Score: 0.93713
#  - 7s - loss: 0.1007 - acc: 0.9669 - val_loss: 0.0909 - val_acc: 0.9683
# Epoch 47/180
# F1 Macro Score: 0.93651
#  - 7s - loss: 0.1018 - acc: 0.9667 - val_loss: 0.0912 - val_acc: 0.9681
# Epoch 48/180
# F1 Macro Score: 0.93703
#  - 7s - loss: 0.1006 - acc: 0.9669 - val_loss: 0.0900 - val_acc: 0.9683
# Epoch 49/180
# F1 Macro Score: 0.93731
#  - 7s - loss: 0.0999 - acc: 0.9669 - val_loss: 0.0899 - val_acc: 0.9684
# Epoch 50/180
# F1 Macro Score: 0.93664
#  - 7s - loss: 0.0992 - acc: 0.9670 - val_loss: 0.0906 - val_acc: 0.9682
# Epoch 51/180
# F1 Macro Score: 0.93710
#  - 7s - loss: 0.0994 - acc: 0.9669 - val_loss: 0.0898 - val_acc: 0.9683
# Epoch 52/180
# F1 Macro Score: 0.93692
#  - 7s - loss: 0.0990 - acc: 0.9670 - val_loss: 0.0897 - val_acc: 0.9682
# Epoch 53/180
# F1 Macro Score: 0.93720
#  - 7s - loss: 0.0979 - acc: 0.9670 - val_loss: 0.0888 - val_acc: 0.9685
# Epoch 54/180
# F1 Macro Score: 0.93672
#  - 7s - loss: 0.0990 - acc: 0.9669 - val_loss: 0.0896 - val_acc: 0.9682
# Epoch 55/180
# F1 Macro Score: 0.93722
#  - 7s - loss: 0.0985 - acc: 0.9669 - val_loss: 0.0884 - val_acc: 0.9684
# Epoch 56/180
# F1 Macro Score: 0.93691
#  - 7s - loss: 0.0984 - acc: 0.9669 - val_loss: 0.0892 - val_acc: 0.9683
# Epoch 57/180
# F1 Macro Score: 0.93728
#  - 7s - loss: 0.0970 - acc: 0.9671 - val_loss: 0.0880 - val_acc: 0.9685
# Epoch 58/180
# F1 Macro Score: 0.93697
#  - 7s - loss: 0.0971 - acc: 0.9671 - val_loss: 0.0879 - val_acc: 0.9684
# Epoch 59/180
# F1 Macro Score: 0.93691
#  - 7s - loss: 0.0974 - acc: 0.9670 - val_loss: 0.0886 - val_acc: 0.9685
# Epoch 60/180
# F1 Macro Score: 0.93710
#  - 7s - loss: 0.0967 - acc: 0.9671 - val_loss: 0.0880 - val_acc: 0.9685
# Epoch 61/180
# F1 Macro Score: 0.93735
#  - 7s - loss: 0.0964 - acc: 0.9671 - val_loss: 0.0874 - val_acc: 0.9685
# Epoch 62/180
# F1 Macro Score: 0.93713
#  - 7s - loss: 0.0962 - acc: 0.9671 - val_loss: 0.0875 - val_acc: 0.9684
# Epoch 63/180
# F1 Macro Score: 0.93736
#  - 7s - loss: 0.0963 - acc: 0.9671 - val_loss: 0.0870 - val_acc: 0.9685
# Epoch 64/180
# F1 Macro Score: 0.93698
#  - 7s - loss: 0.0957 - acc: 0.9672 - val_loss: 0.0874 - val_acc: 0.9684
# Epoch 65/180
# F1 Macro Score: 0.93663
#  - 7s - loss: 0.0969 - acc: 0.9670 - val_loss: 0.0889 - val_acc: 0.9683
# Epoch 66/180
# F1 Macro Score: 0.93730
#  - 7s - loss: 0.0954 - acc: 0.9671 - val_loss: 0.0868 - val_acc: 0.9685
# Epoch 67/180
# F1 Macro Score: 0.93726
#  - 7s - loss: 0.0951 - acc: 0.9672 - val_loss: 0.0867 - val_acc: 0.9686
# Epoch 68/180
# F1 Macro Score: 0.93408
#  - 7s - loss: 0.0962 - acc: 0.9669 - val_loss: 0.0928 - val_acc: 0.9672
# Epoch 69/180
# F1 Macro Score: 0.93722
#  - 7s - loss: 0.0962 - acc: 0.9669 - val_loss: 0.0872 - val_acc: 0.9685
# Epoch 70/180
# F1 Macro Score: 0.93674
#  - 7s - loss: 0.0985 - acc: 0.9667 - val_loss: 0.0875 - val_acc: 0.9685
# Epoch 71/180
# F1 Macro Score: 0.93730
#  - 7s - loss: 0.0968 - acc: 0.9668 - val_loss: 0.0884 - val_acc: 0.9685
# Epoch 72/180
# F1 Macro Score: 0.93747
# ...
#  - 7s - loss: 0.0873 - acc: 0.9686 - val_loss: 0.0837 - val_acc: 0.9688
# Epoch 39/180
# F1 Macro Score: 0.93942
#  - 7s - loss: 0.0864 - acc: 0.9688 - val_loss: 0.0839 - val_acc: 0.9687
# Epoch 40/180
# F1 Macro Score: 0.93807
#  - 7s - loss: 0.0864 - acc: 0.9688 - val_loss: 0.0862 - val_acc: 0.9680
# Epoch 41/180
# F1 Macro Score: 0.93970
#  - 7s - loss: 0.0863 - acc: 0.9689 - val_loss: 0.0831 - val_acc: 0.9689
# Epoch 42/180
# F1 Macro Score: 0.93982
#  - 7s - loss: 0.0849 - acc: 0.9691 - val_loss: 0.0832 - val_acc: 0.9688
# Epoch 43/180
# F1 Macro Score: 0.94057
#  - 7s - loss: 0.0864 - acc: 0.9688 - val_loss: 0.0824 - val_acc: 0.9692
# Epoch 44/180
# F1 Macro Score: 0.94026
#  - 7s - loss: 0.0855 - acc: 0.9690 - val_loss: 0.0823 - val_acc: 0.9691
# Epoch 45/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0849 - acc: 0.9692 - val_loss: 0.0821 - val_acc: 0.9692
# Epoch 46/180
# F1 Macro Score: 0.94003
#  - 7s - loss: 0.0853 - acc: 0.9691 - val_loss: 0.0828 - val_acc: 0.9689
# Epoch 47/180
# F1 Macro Score: 0.94013
#  - 7s - loss: 0.0847 - acc: 0.9692 - val_loss: 0.0830 - val_acc: 0.9690
# Epoch 48/180
# F1 Macro Score: 0.93994
#  - 7s - loss: 0.0844 - acc: 0.9693 - val_loss: 0.0822 - val_acc: 0.9691
# Epoch 49/180
# F1 Macro Score: 0.93989
#  - 7s - loss: 0.0844 - acc: 0.9693 - val_loss: 0.0826 - val_acc: 0.9689
# Epoch 50/180
# F1 Macro Score: 0.93943
#  - 7s - loss: 0.0846 - acc: 0.9692 - val_loss: 0.0835 - val_acc: 0.9686
# Epoch 51/180
# F1 Macro Score: 0.94060
#  - 8s - loss: 0.0840 - acc: 0.9694 - val_loss: 0.0815 - val_acc: 0.9693
# Epoch 52/180
# F1 Macro Score: 0.94049
#  - 7s - loss: 0.0833 - acc: 0.9695 - val_loss: 0.0815 - val_acc: 0.9692
# Epoch 53/180
# F1 Macro Score: 0.94033
#  - 7s - loss: 0.0833 - acc: 0.9695 - val_loss: 0.0817 - val_acc: 0.9691
# Epoch 54/180
# F1 Macro Score: 0.93974
#  - 8s - loss: 0.0830 - acc: 0.9696 - val_loss: 0.0828 - val_acc: 0.9689
# Epoch 55/180
# F1 Macro Score: 0.93979
#  - 7s - loss: 0.0831 - acc: 0.9696 - val_loss: 0.0824 - val_acc: 0.9689
# Epoch 56/180
# F1 Macro Score: 0.93968
#  - 7s - loss: 0.0829 - acc: 0.9696 - val_loss: 0.0824 - val_acc: 0.9689
# Epoch 57/180
# F1 Macro Score: 0.93982
#  - 7s - loss: 0.0832 - acc: 0.9696 - val_loss: 0.0824 - val_acc: 0.9688
# Epoch 58/180
# F1 Macro Score: 0.94016
#  - 7s - loss: 0.0828 - acc: 0.9696 - val_loss: 0.0822 - val_acc: 0.9690
# Epoch 59/180
# F1 Macro Score: 0.94044
#  - 7s - loss: 0.0825 - acc: 0.9696 - val_loss: 0.0816 - val_acc: 0.9692
# Epoch 60/180
# F1 Macro Score: 0.94060
#  - 7s - loss: 0.0824 - acc: 0.9697 - val_loss: 0.0817 - val_acc: 0.9693
# Epoch 61/180
# F1 Macro Score: 0.94029
#  - 7s - loss: 0.0825 - acc: 0.9697 - val_loss: 0.0818 - val_acc: 0.9692
# Epoch 62/180
# F1 Macro Score: 0.94049
#  - 7s - loss: 0.0820 - acc: 0.9698 - val_loss: 0.0815 - val_acc: 0.9693
# Epoch 63/180
# F1 Macro Score: 0.94018
#  - 7s - loss: 0.0827 - acc: 0.9697 - val_loss: 0.0818 - val_acc: 0.9691
# Epoch 64/180
# F1 Macro Score: 0.93863
#  - 7s - loss: 0.0849 - acc: 0.9689 - val_loss: 0.0840 - val_acc: 0.9686
# Epoch 65/180
# F1 Macro Score: 0.93811
#  - 7s - loss: 0.0930 - acc: 0.9671 - val_loss: 0.0858 - val_acc: 0.9684
# Epoch 66/180
# F1 Macro Score: 0.93989
#  - 7s - loss: 0.0848 - acc: 0.9694 - val_loss: 0.0829 - val_acc: 0.9691
# Epoch 67/180
# F1 Macro Score: 0.94053
#  - 7s - loss: 0.0830 - acc: 0.9697 - val_loss: 0.0821 - val_acc: 0.9691
# Epoch 68/180
# F1 Macro Score: 0.94050
#  - 7s - loss: 0.0828 - acc: 0.9697 - val_loss: 0.0817 - val_acc: 0.9692
# Epoch 69/180
# F1 Macro Score: 0.94053
#  - 7s - loss: 0.0825 - acc: 0.9697 - val_loss: 0.0816 - val_acc: 0.9693
# Epoch 70/180
# F1 Macro Score: 0.94049
#  - 7s - loss: 0.0822 - acc: 0.9698 - val_loss: 0.0813 - val_acc: 0.9692
# Epoch 71/180
# F1 Macro Score: 0.94056
#  - 7s - loss: 0.0818 - acc: 0.9699 - val_loss: 0.0816 - val_acc: 0.9692
# Epoch 72/180
# F1 Macro Score: 0.94015
#  - 7s - loss: 0.0829 - acc: 0.9697 - val_loss: 0.0813 - val_acc: 0.9691
# Epoch 73/180
# F1 Macro Score: 0.94061
#  - 7s - loss: 0.0815 - acc: 0.9699 - val_loss: 0.0811 - val_acc: 0.9693
# Epoch 74/180
# F1 Macro Score: 0.94079
#  - 7s - loss: 0.0823 - acc: 0.9697 - val_loss: 0.0810 - val_acc: 0.9694
# Epoch 75/180
# F1 Macro Score: 0.94041
#  - 8s - loss: 0.0822 - acc: 0.9698 - val_loss: 0.0819 - val_acc: 0.9691
# Epoch 76/180
# F1 Macro Score: 0.94034
#  - 7s - loss: 0.0817 - acc: 0.9700 - val_loss: 0.0817 - val_acc: 0.9691
# Epoch 77/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0811 - acc: 0.9700 - val_loss: 0.0810 - val_acc: 0.9693
# Epoch 78/180
# F1 Macro Score: 0.93978
#  - 7s - loss: 0.0817 - acc: 0.9699 - val_loss: 0.0823 - val_acc: 0.9689
# Epoch 79/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0815 - acc: 0.9700 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 80/180
# F1 Macro Score: 0.94037
#  - 7s - loss: 0.0817 - acc: 0.9700 - val_loss: 0.0817 - val_acc: 0.9691
# Epoch 81/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0812 - acc: 0.9700 - val_loss: 0.0813 - val_acc: 0.9692
# Epoch 82/180
# F1 Macro Score: 0.94028
#  - 7s - loss: 0.0807 - acc: 0.9701 - val_loss: 0.0817 - val_acc: 0.9691
# Epoch 83/180
# F1 Macro Score: 0.94015
#  - 7s - loss: 0.0809 - acc: 0.9700 - val_loss: 0.0813 - val_acc: 0.9691
# Epoch 84/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0809 - acc: 0.9700 - val_loss: 0.0811 - val_acc: 0.9693
# Epoch 85/180
# F1 Macro Score: 0.94039
#  - 7s - loss: 0.0819 - acc: 0.9699 - val_loss: 0.0816 - val_acc: 0.9691
# Epoch 86/180
# F1 Macro Score: 0.94036
#  - 7s - loss: 0.0809 - acc: 0.9700 - val_loss: 0.0815 - val_acc: 0.9691
# Epoch 87/180
# F1 Macro Score: 0.94060
#  - 8s - loss: 0.0803 - acc: 0.9702 - val_loss: 0.0814 - val_acc: 0.9693
# Epoch 88/180
# F1 Macro Score: 0.93984
#  - 8s - loss: 0.0804 - acc: 0.9702 - val_loss: 0.0815 - val_acc: 0.9691
# Epoch 89/180
# F1 Macro Score: 0.94078
#  - 8s - loss: 0.0802 - acc: 0.9702 - val_loss: 0.0809 - val_acc: 0.9694
# Epoch 90/180
# F1 Macro Score: 0.94043
#  - 8s - loss: 0.0810 - acc: 0.9700 - val_loss: 0.0812 - val_acc: 0.9692
# Epoch 91/180
# F1 Macro Score: 0.94071
#  - 8s - loss: 0.0801 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 92/180
# F1 Macro Score: 0.94078
#  - 8s - loss: 0.0802 - acc: 0.9702 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 93/180
# F1 Macro Score: 0.94072
#  - 8s - loss: 0.0800 - acc: 0.9703 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 94/180
# F1 Macro Score: 0.94074
#  - 8s - loss: 0.0800 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 95/180
# F1 Macro Score: 0.94080
#  - 8s - loss: 0.0799 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 96/180
# F1 Macro Score: 0.94079
#  - 8s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 97/180
# F1 Macro Score: 0.94072
#  - 8s - loss: 0.0815 - acc: 0.9700 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 98/180
# F1 Macro Score: 0.94071
#  - 8s - loss: 0.0803 - acc: 0.9702 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 99/180
# F1 Macro Score: 0.94072
#  - 8s - loss: 0.0800 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 100/180
# F1 Macro Score: 0.94085
#  - 8s - loss: 0.0797 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 101/180
# F1 Macro Score: 0.94078
#  - 8s - loss: 0.0800 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 102/180
# F1 Macro Score: 0.94078
#  - 8s - loss: 0.0796 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 103/180
# F1 Macro Score: 0.94074
#  - 8s - loss: 0.0809 - acc: 0.9701 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 104/180
# F1 Macro Score: 0.94083
#  - 8s - loss: 0.0801 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 105/180
# F1 Macro Score: 0.94075
#  - 8s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 106/180
# F1 Macro Score: 0.94074
#  - 8s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 107/180
# F1 Macro Score: 0.94071
#  - 8s - loss: 0.0797 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 108/180
# F1 Macro Score: 0.94074
#  - 8s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 109/180
# F1 Macro Score: 0.94076
#  - 8s - loss: 0.0795 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 110/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0803 - acc: 0.9701 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 111/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0795 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 112/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0797 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 113/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0793 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 114/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0798 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 115/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0796 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 116/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 117/180
# F1 Macro Score: 0.94074
#  - 7s - loss: 0.0801 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 118/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 119/180
# F1 Macro Score: 0.94074
#  - 8s - loss: 0.0796 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 120/180
# F1 Macro Score: 0.94063
#  - 7s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 121/180
# F1 Macro Score: 0.94078
#  - 7s - loss: 0.0794 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 122/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0795 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 123/180
# F1 Macro Score: 0.94080
#  - 8s - loss: 0.0806 - acc: 0.9702 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 124/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0802 - acc: 0.9702 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 125/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 126/180
# F1 Macro Score: 0.94056
#  - 7s - loss: 0.0796 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 127/180
# F1 Macro Score: 0.94066
#  - 8s - loss: 0.0797 - acc: 0.9703 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 128/180
# F1 Macro Score: 0.94058
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0809 - val_acc: 0.9692
# Epoch 129/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0798 - acc: 0.9703 - val_loss: 0.0810 - val_acc: 0.9693
# Epoch 130/180
# F1 Macro Score: 0.94067
#  - 8s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 131/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0794 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 132/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 133/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 134/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 135/180
# F1 Macro Score: 0.94082
#  - 7s - loss: 0.0797 - acc: 0.9703 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 136/180
# F1 Macro Score: 0.94074
#  - 7s - loss: 0.0792 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 137/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0797 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 138/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0792 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 139/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0796 - acc: 0.9704 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 140/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0791 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 141/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0796 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 142/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0793 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 143/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0795 - acc: 0.9704 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 144/180
# F1 Macro Score: 0.94054
#  - 7s - loss: 0.0792 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 145/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0795 - acc: 0.9703 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 146/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0793 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 147/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0793 - acc: 0.9705 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 148/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0796 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 149/180
# F1 Macro Score: 0.94074
#  - 7s - loss: 0.0791 - acc: 0.9704 - val_loss: 0.0807 - val_acc: 0.9694
# Epoch 150/180
# F1 Macro Score: 0.94070
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 151/180
# F1 Macro Score: 0.94050
#  - 7s - loss: 0.0794 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 152/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0809 - val_acc: 0.9694
# Epoch 153/180
# F1 Macro Score: 0.94072
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 154/180
# F1 Macro Score: 0.94080
#  - 7s - loss: 0.0790 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9694
# Epoch 155/180
# F1 Macro Score: 0.94081
#  - 7s - loss: 0.0794 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 156/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0792 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 157/180
# F1 Macro Score: 0.94067
#  - 7s - loss: 0.0789 - acc: 0.9706 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 158/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0790 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 159/180
# F1 Macro Score: 0.94065
#  - 7s - loss: 0.0787 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 160/180
# F1 Macro Score: 0.94077
#  - 7s - loss: 0.0791 - acc: 0.9705 - val_loss: 0.0807 - val_acc: 0.9693
# Epoch 161/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0796 - acc: 0.9703 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 162/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0792 - acc: 0.9704 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 163/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0790 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9692
# Epoch 164/180
# F1 Macro Score: 0.94069
#  - 7s - loss: 0.0791 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 165/180
# F1 Macro Score: 0.94074
#  - 7s - loss: 0.0788 - acc: 0.9706 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 166/180
# F1 Macro Score: 0.94076
#  - 7s - loss: 0.0791 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 167/180
# F1 Macro Score: 0.94075
#  - 7s - loss: 0.0791 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 168/180
# F1 Macro Score: 0.94074
#  - 7s - loss: 0.0787 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 169/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0788 - acc: 0.9706 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 170/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0788 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 171/180
# F1 Macro Score: 0.94059
#  - 7s - loss: 0.0805 - acc: 0.9701 - val_loss: 0.0809 - val_acc: 0.9692
# Epoch 172/180
# F1 Macro Score: 0.94062
#  - 7s - loss: 0.0792 - acc: 0.9705 - val_loss: 0.0811 - val_acc: 0.9692
# Epoch 173/180
# F1 Macro Score: 0.94057
#  - 7s - loss: 0.0797 - acc: 0.9703 - val_loss: 0.0810 - val_acc: 0.9693
# Epoch 174/180
# F1 Macro Score: 0.94073
#  - 7s - loss: 0.0793 - acc: 0.9704 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 175/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0788 - acc: 0.9706 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 176/180
# F1 Macro Score: 0.94066
#  - 7s - loss: 0.0790 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 177/180
# F1 Macro Score: 0.94068
#  - 7s - loss: 0.0790 - acc: 0.9705 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 178/180
# F1 Macro Score: 0.94071
#  - 7s - loss: 0.0789 - acc: 0.9705 - val_loss: 0.0808 - val_acc: 0.9693
# Epoch 179/180
# F1 Macro Score: 0.94057
#  - 7s - loss: 0.0789 - acc: 0.9706 - val_loss: 0.0809 - val_acc: 0.9693
# Epoch 180/180
# F1 Macro Score: 0.94064
#  - 7s - loss: 0.0787 - acc: 0.9706 - val_loss: 0.0808 - val_acc: 0.9693
# Training fold 5 completed. macro f1 score : 0.94064
# Training completed. oof macro f1 score : 0.94022
# submission save path: ./../data/output/submission_nb041_cv_0.9402.csv
# probas save path: ./../data/output_ignore/probas_nb041_cv_0.9402
# Training completed...
# CPU times: user 1h 34min 23s, sys: 13min 19s, total: 1h 47min 42s
# Wall time: 1h 54min 36s

# %% [markdown]
# # analysis

# %%
df_tr = pd.read_csv(PATH_TRAIN)

# %%
batch_list = []
for n in range(10):
    batchs = np.ones(500000)*n
    batch_list.append(batchs.astype(int))
batch_list = np.hstack(batch_list)
df_tr['batch'] = batch_list

# %%
# group 特徴量を作成
group = group_feat_train(df_tr)
df_tr = pd.concat([df_tr, group], axis=1)

# %%
y = df_tr['open_channels'].values

# %%
oof = np.argmax(oof_, axis=1).astype(int)

# %%
for group in sorted(df_tr['group'].unique()):
    idxs = df_tr['group'] == group
    oof_grp = oof[idxs].astype(int)
    y_grp = y[idxs]
    print(f'group_score({group}): {f1_score(y_grp, oof_grp, average="micro"):4f}')
# Out:
# group_score(0): 0.999624
# group_score(1): 0.978517
# group_score(2): 0.978822
# group_score(3): 0.997829
# group_score(4): 0.891544

# %%
max_ = df_tr.loc[df_tr['batch']==3]['signal'].max() 
min_ = df_tr.loc[df_tr['batch']==3]['signal'].min() 
idxs = (df_tr['batch']==7) & (df_tr['signal']>max_)
df_tr['signal'][idxs] = max_
idxs = (df_tr['batch']==7) & (df_tr['signal']<min_)
df_tr['signal'][idxs] = min_

# %% [markdown]
# <br>
#
# 可視化

# %%
x_idx = np.arange(len(df_tr))
idxs = y != oof

failed = np.zeros(len(df_tr))
failed[idxs] = 1

# %%
n = 200
b = np.ones(n)/n
failed_move = np.convolve(failed, b, mode='same')

# %%
fig, axs = plt.subplots(2, 1, figsize=(20, 6))
axs = axs.ravel()
# fig = plt.figure(figsize=(20, 3))

for i_gr, group in enumerate(sorted(df_tr['group'].unique())):
    idxs = df_tr['group'] == group
    axs[0].plot(np.arange(len(df_tr))[idxs], df_tr['signal'].values[idxs], color=cp[i_gr], label=f'group={group}')
for x in range(10): 
    axs[0].axvline(x*500000 + 500000, color='gray') 
    axs[0].text(x*500000 + 250000, 5, x)
axs[0].plot(x_idx, failed_move*10, '.', color='black', label='failed_mv')
axs[0].set_xlim(0, 5500000)
axs[0].legend()

axs[1].plot(x_idx, y)
axs[1].set_xlim(0, 5500000)

# fig.legend()
# Out:
# (0, 5500000)
