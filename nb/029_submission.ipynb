# %% [markdown]
# # Overview
#
# - nb028 を group ごとに学習する
# - nb027 に group の定義図がある

# %% [markdown]
# # Const

# %%
NB = '029'
isSmallSet = False
if isSmallSet:
    LENGTH = 7000
else:
    LENGTH = 500_000

PATH_TRAIN = './../data/input/train_clean.csv'
PATH_TEST = './../data/input/test_clean.csv'
PATH_SMPLE_SUB = './../data/input/sample_submission.csv'
DIR_OUTPUT = './../data/output/'
DIR_OUTPUT_IGNORE = './../data/output_ignore/'
cp = ['#f8b195', '#f67280', '#c06c84', '#6c5b7b', '#355c7d']
sr = 10*10**3  # 10 kHz

# %% [markdown]
# # Import everything I need :)

# %%
import warnings
warnings.filterwarnings('ignore')
import time
import gc
import itertools
import multiprocessing
import numpy as np
from scipy import signal
# from pykalman import KalmanFilter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fastprogress import progress_bar
from lightgbm import LGBMRegressor
from sklearn.model_selection import KFold, train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, mean_absolute_error, confusion_matrix
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
# from sklearn.svm import SVR
from sklearn.linear_model import Lasso
# from dtreeviz.trees import dtreeviz

# %% [markdown]
# # My function

# %%
def f1_macro(true, pred):
    return f1_score(true, pred, average='macro')

def get_df_batch(df, batch):
    idxs = df['batch'] == batch
    assert any(idxs), 'そのようなbatchはありません'
    return df[idxs]
    
def get_signal_mv_mean(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).mean().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_std(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).std().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_min(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).min().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def get_signal_mv_max(df, n=3001):
    signal_mv = np.zeros(len(df))
    for bt in df['batch'].unique():
        idxs = df['batch'] == bt
        _signal_mv = df['signal'][idxs].rolling(n, center=True).max().interpolate('spline', order=5, limit_direction='both').values
        signal_mv[idxs] = _signal_mv
    return signal_mv

def group_feat_train(train):
    # group init
    train['group'] = int(0)

    # group 1
    idxs = (train['batch'] == 3) | (train['batch'] == 7)
    train['group'][idxs] = int(1)

    # group 2
    idxs = (train['batch'] == 5) | (train['batch'] == 8)
    train['group'][idxs] = int(2)

    # group 3
    idxs = (train['batch'] == 2) | (train['batch'] == 6)
    train['group'][idxs] = int(3)

    # group 4
    idxs = (train['batch'] == 4) | (train['batch'] == 9)
    train['group'][idxs] = int(4)
    
    return train[['group']]

def group_feat_test(test):
    # group init
    test['group'] = int(0)
    x_idx = np.arange(len(test))

    # group 1
    idxs = (100000<=x_idx) & (x_idx<200000)
    test['group'][idxs] = int(1)
    idxs = (900000<=x_idx) & (x_idx<=1000000)
    test['group'][idxs] = int(1)

    # group 2
    idxs = (200000<=x_idx) & (x_idx<300000)
    test['group'][idxs] = int(2)
    idxs = (600000<=x_idx) & (x_idx<700000)
    test['group'][idxs] = int(2)

    # group 3
    idxs = (400000<=x_idx) & (x_idx<500000)
    test['group'][idxs] = int(3)

    # group 4
    idxs = (500000<=x_idx) & (x_idx<600000)
    test['group'][idxs] = int(4)
    idxs = (700000<=x_idx) & (x_idx<800000)
    test['group'][idxs] = int(4)
    
    return test[['group']]


class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, X_valid, y_valid):
        self.n_feat = len(X_valid.columns)
        if self.metric == 'auc':
            y_valid_score = self.model.predict_proba(X_valid)[:, 1]
            fpr, tpr, thresholds = roc_curve(y_valid, y_valid_score)
            self.base_score = auc(fpr, tpr)
        else:
            pred = np.round(self.model.predict(X_valid)).astype('int8')
            self.base_score = self.metric(y_valid, pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(X_valid.columns):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            y_valid_pred = self.model.predict(df_perm)
            if self.metric == 'auc':
                y_valid_score = self.model.predict_proba(df_perm)[:, 1]
                fpr, tpr, thresholds = roc_curve(y_valid, y_valid_score)
                score = auc(fpr, tpr)
            else:
                score = self.metric(y_valid, np.round(y_valid_pred).astype('int8'))
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')

def plot_corr(df, abs_=False, threshold=0.95):
    if abs_==True:
        corr = df.corr().abs()>threshold
        vmin = 0
    else:
        corr = df.corr()
        vmin = -1

    # Plot
    fig, ax = plt.subplots(figsize=(12, 10), dpi=100)
    fig.patch.set_facecolor('white')
    sns.heatmap(corr,
                xticklabels=df.corr().columns,
                yticklabels=df.corr().columns,
                vmin=vmin,
                vmax=1,
                center=0, 
                annot=False)

    # Decorations
    ax.set_title('Correlation', fontsize=22)

def get_low_corr_column(df, threshold):

    df_corr = df.corr()
    df_corr = abs(df_corr)
    columns = df_corr.columns

    # 対角線の値を0にする
    for i in range(0, len(columns)):
        df_corr.iloc[i, i] = 0

    while True:
        columns = df_corr.columns
        max_corr = 0.0
        query_column = None
        target_column = None

        df_max_column_value = df_corr.max()
        max_corr = df_max_column_value.max()
        query_column = df_max_column_value.idxmax()
        target_column = df_corr[query_column].idxmax()

        if max_corr < threshold:
            # しきい値を超えるものがなかったため終了
            break
        else:
            # しきい値を超えるものがあった場合
            delete_column = None
            saved_column = None

            # その他との相関の絶対値が大きい方を除去
            if sum(df_corr[query_column]) <= sum(df_corr[target_column]):
                delete_column = target_column
                saved_column = query_column
            else:
                delete_column = query_column
                saved_column = target_column

            # 除去すべき特徴を相関行列から消す（行、列）
            df_corr.drop([delete_column], axis=0, inplace=True)
            df_corr.drop([delete_column], axis=1, inplace=True)

    return df_corr.columns  # 相関が高い特徴量を除いた名前リスト

def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        if col!='open_channels':
            col_type = df[col].dtypes
            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()
                if str(col_type)[:3] == 'int':
                    if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

def plot_confusion_matrix(truth, pred, classes, normalize=False, title=''):
    cm = confusion_matrix(truth, pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    plt.figure(figsize=(10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix', size=15)
    plt.colorbar(fraction=0.046, pad=0.04)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.grid(False)
    plt.tight_layout()

# %%
def train_lgbm(X, y, X_te, lgbm_params, random_state=5, n_fold=5, verbose=50, early_stopping_rounds=100, show_fig=True):
    # using features
    print(f'features({len(X.columns)}): \n{X.columns}') if not verbose==0 else None

#     folds = KFold(n_splits=n_fold, shuffle=True, random_state=random_state)
    folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=random_state)

    scores = []
    oof = np.zeros(len(X))
    oof_round = np.zeros(len(X))
    test_pred = np.zeros(len(X_te))
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for fold_n, (train_idx, valid_idx) in enumerate(folds.split(X, y=y)):
        if  verbose==0:
            pass
        else:
            print('\n------------------')
            print(f'- Fold {fold_n + 1}/{N_FOLD} started at {time.ctime()}')

        # prepare dataset
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]

        # train
        model = LGBMRegressor(**lgbm_params, n_estimators=N_ESTIMATORS)
        model.fit(X_train, y_train,
                  eval_set=[(X_train, y_train), (X_valid, y_valid)],
                  verbose=verbose,
                  early_stopping_rounds=early_stopping_rounds,
                  categorical_feature=['group'],
                 )

        # pred
        y_valid_pred = model.predict(X_valid, model.best_iteration_)
        y_valid_pred_round = np.round(y_valid_pred).astype('int8')
        _test_pred = model.predict(X_te, model.best_iteration_)

        if show_fig==False:
            pass
        else:
            # permutation importance
            pi = permutation_importance(model, f1_macro) # model と metric を渡す
            pi.compute(X_valid, y_valid)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])

        # result
        oof[valid_idx] = y_valid_pred
        oof_round[valid_idx] = y_valid_pred_round
        score = f1_score(y_valid, y_valid_pred_round, average='macro')
        scores.append(score)
        test_pred += _test_pred
        if verbose==0:
            pass
        else:
            print(f'---> f1-score(macro) valid: {f1_score(y_valid, y_valid_pred_round, average="macro"):.4f}')
            print('')


    print('====== finish ======')
    print('score list:', scores)
    print('CV mean score(f1_macro): {0:.4f}, std: {1:.4f}'.format(np.mean(scores), np.std(scores)))
    print(f'oof score(f1_macro): {f1_score(y, oof_round, average="macro"):.4f}')
    for group in sorted(X['group'].unique()):
        idxs = X['group'] == group
        oof_round_grp = oof_round[idxs].astype(int)
        y_grp = y[idxs]
        print(f'group_score({group}): {f1_macro(y_grp, oof_round_grp):4f}')
        print('')


    if show_fig==False:
        pass
    else:
        # visualization
        plt.figure(figsize=(5, 5))
        plt.plot([0, 10], [0, 10], color='gray')
        plt.scatter(y, oof, alpha=0.05, color=cp[1])
        plt.xlabel('true')
        plt.ylabel('pred')
        plt.show()
          
        # confusion_matrix
        plot_confusion_matrix(y, oof_round, classes=np.arange(11))
        
        
        # permutation importance
        plt.figure(figsize=(15, int(0.25*len(X.columns))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=False)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()

    # submission
    test_pred = test_pred/N_FOLD
    test_pred_round = np.round(test_pred).astype('int8')
      
    return test_pred_round, test_pred, oof_round, oof, type(model).__name__

# %%
def train_test_split_lgbm(X, y, X_te, lgbm_params, random_state=5, test_size=0.3, verbose=50, early_stopping_rounds=100, show_fig=True):
    # using features
    print(f'features({len(X.columns)}): \n{X.columns}') if not verbose==0 else None

#     folds = KFold(n_splits=n_fold, shuffle=True, random_state=random_state)
#     folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=random_state)
    
    # prepare dataset
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=test_size, random_state=random_state)

    # train
    model = LGBMRegressor(**lgbm_params, n_estimators=N_ESTIMATORS)
    model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_valid, y_valid)],
              verbose=verbose,
              early_stopping_rounds=early_stopping_rounds)

    # pred
    oof = model.predict(X_valid, model.best_iteration_)
    oof_round = np.round(oof).astype('int8')
    test_pred = model.predict(X_te, model.best_iteration_)
    test_pred_round = np.round(test_pred).astype('int8')

    print('====== finish ======')
    print(f'oof score(f1_macro): {f1_score(y_valid, oof_round, average="macro"):.4f}')
    print('')


    if show_fig==False:
        pass
    else:
        # visualization
        plt.figure(figsize=(5, 5))
        plt.plot([0, 10], [0, 10], color='gray')
        plt.scatter(y_valid, oof, alpha=0.05, color=cp[1])
        plt.xlabel('true')
        plt.ylabel('pred')
        plt.show()
          
        # confusion_matrix
        plot_confusion_matrix(y_valid, oof_round, classes=np.arange(11))
        
        # permutation importance
        pi = permutation_importance(model, f1_macro) # model と metric を渡す
        pi.compute(X_valid, y_valid)
        pi.show_permutation_importance(score_type='accuracy')  # loss or accuracy
        plt.show()

    return test_pred_round, test_pred, oof_round, oof, type(model).__name__

# %% [markdown]
# <br>
#
# ref: https://www.kaggle.com/martxelo/fe-and-ensemble-mlp-and-lgbm

# %%
def calc_gradients(s, n_grads=4):
    '''
    Calculate gradients for a pandas series. Returns the same number of samples
    '''
    grads = pd.DataFrame()
    
    g = s.values
    for i in range(n_grads):
        g = np.gradient(g)
        grads['grad_' + str(i+1)] = g
        
    return grads


def calc_low_pass(s, n_filts=10):
    '''
    Applies low pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.3, n_filts)
#     wns = [0.3244]
    
    low_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='low')
        zi = signal.lfilter_zi(b, a)
        low_pass['lowpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        low_pass['lowpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return low_pass

def calc_high_pass(s, n_filts=10):
    '''
    Applies high pass filters to the signal. Left delayed and no delayed
    '''
    wns = np.logspace(-2, -0.1, n_filts)
#     wns = [0.0100, 0.0264, 0.0699, 0.3005, 0.4885, 0.7943]
    
    high_pass = pd.DataFrame()
    x = s.values
    for wn in wns:
        b, a = signal.butter(1, Wn=wn, btype='high')
        zi = signal.lfilter_zi(b, a)
        high_pass['highpass_lf_' + str('%.4f' %wn)] = signal.lfilter(b, a, x, zi=zi*x[0])[0]
        high_pass['highpass_ff_' + str('%.4f' %wn)] = signal.filtfilt(b, a, x)
        
    return high_pass

def calc_roll_stats(s, windows=[10, 50, 100, 500, 1000, 3000]):
    '''
    Calculates rolling stats like mean, std, min, max...
    '''
    roll_stats = pd.DataFrame()
    for w in windows:
        roll_stats['roll_mean_' + str(w)] = s.rolling(window=w, min_periods=1).mean().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_std_' + str(w)] = s.rolling(window=w, min_periods=1).std().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_min_' + str(w)] = s.rolling(window=w, min_periods=1).min().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_max_' + str(w)] = s.rolling(window=w, min_periods=1).max().interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_range_' + str(w)] = roll_stats['roll_max_' + str(w)] - roll_stats['roll_min_' + str(w)]
        roll_stats['roll_q10_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.10).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q25_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.25).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q50_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.50).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q75_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.75).interpolate('spline', order=5, limit_direction='both')
        roll_stats['roll_q90_' + str(w)] = s.rolling(window=w, min_periods=1).quantile(0.90).interpolate('spline', order=5, limit_direction='both')
    
    # add zeros when na values (std)
#     roll_stats = roll_stats.fillna(value=0)
             
    return roll_stats

def calc_ewm(s, windows=[10, 50, 100, 500, 1000, 3000]):
    '''
    Calculates exponential weighted functions
    '''
    ewm = pd.DataFrame()
    for w in windows:
        ewm['ewm_mean_' + str(w)] = s.ewm(span=w, min_periods=1).mean()
        ewm['ewm_std_' + str(w)] = s.ewm(span=w, min_periods=1).std()
        
    # add zeros when na values (std)
    ewm = ewm.fillna(value=0)
        
    return ewm



def divide_and_add_features(s, signal_size=500000):
    '''
    Divide the signal in bags of "signal_size".
    Normalize the data dividing it by 15.0
    '''
    # normalize
    s = s/15.0
    
    ls = []
    for i in progress_bar(range(int(s.shape[0]/signal_size))):
        sig = s[i*signal_size:(i+1)*signal_size].copy().reset_index(drop=True)
        sig_featured = add_features(sig)
        ls.append(sig_featured)
    
    return pd.concat(ls, axis=0)

# %% [markdown]
# <br>
#
# ref: https://www.kaggle.com/nxrprime/single-model-lgbm-kalman-filter-ii

# %%
def Kalman1D(observations,damping=1):
    # To return the smoothed time series data
    observation_covariance = damping
    initial_value_guess = observations[0]
    transition_matrix = 1
    transition_covariance = 0.1
    initial_value_guess
    kf = KalmanFilter(
            initial_state_mean=initial_value_guess,
            initial_state_covariance=observation_covariance,
            observation_covariance=observation_covariance,
            transition_covariance=transition_covariance,
            transition_matrices=transition_matrix
        )
    pred_state, state_cov = kf.smooth(observations)
    return pred_state

# %% [markdown]
# # Preparation

# %% [markdown]
# setting

# %%
sns.set()

# %% [markdown]
# <br>
#
# load dataset

# %%
df_tr = pd.read_csv(PATH_TRAIN)
df_te = pd.read_csv(PATH_TEST)

# %% [markdown]
# <br>
#
# 処理のしやすさのために、バッチ番号を振る

# %%
batch_list = []
for n in range(10):
    batchs = np.ones(500000)*n
    batch_list.append(batchs.astype(int))
batch_list = np.hstack(batch_list)
df_tr['batch'] = batch_list

batch_list = []
for n in range(4):
    batchs = np.ones(500000)*n
    batch_list.append(batchs.astype(int))
batch_list = np.hstack(batch_list)
df_te['batch'] = batch_list

# %% [markdown]
# <br>
#
# smallset?

# %%
if isSmallSet:
    print('small set mode')
    # train
    batchs = df_tr['batch'].values
    dfs = []
    for i_bt, bt in enumerate(df_tr['batch'].unique()):
        idxs = batchs == bt
        _df = df_tr[idxs][:LENGTH].copy()
        dfs.append(_df)
    df_tr = pd.concat(dfs).reset_index(drop=True)
    
    # test
    batchs = df_te['batch'].values
    dfs = []
    for i_bt, bt in enumerate(df_te['batch'].unique()):
        idxs = batchs == bt
        _df = df_te[idxs][:LENGTH].copy()
        dfs.append(_df)
    df_te = pd.concat(dfs).reset_index(drop=True)

# %% [markdown]
# # Train

# %%
def add_features(s):
    '''
    All calculations together
    '''
    feat_list = [s]
    feat_list.append(calc_gradients(s))
    feat_list.append(calc_low_pass(s))
    feat_list.append(calc_high_pass(s))
    feat_list.append(calc_roll_stats(s))
    feat_list.append(calc_ewm(s))
    
    return pd.concat(feat_list, axis=1)

# %%
# %%time
X = divide_and_add_features(df_tr['signal'], signal_size=LENGTH)
X = reduce_mem_usage(X)
_feats = get_low_corr_column(X, threshold=0.99).to_list()
_feats.append('signal')
X = X[_feats]
X = X.reset_index(drop=True)

X_te = divide_and_add_features(df_te['signal'], signal_size=LENGTH)
X_te = reduce_mem_usage(X_te)
X_te = X_te[_feats]
X_te = X_te.reset_index(drop=True)

y = df_tr['open_channels'].values
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 02:33<00:00]
#     </div>
# Mem. usage decreased to 1153.95 Mb (74.4% reduction)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:48<00:00]
#     </div>
# Mem. usage decreased to 461.58 Mb (74.4% reduction)
# CPU times: user 6min 5s, sys: 2min 6s, total: 8min 11s
# Wall time: 8min 11s

# %%
# group 特徴量を作成
group = group_feat_train(df_tr)
X = pd.concat([X, group], axis=1)

group = group_feat_test(df_te)
X_te = pd.concat([X_te, group], axis=1)

# %%
# Configuration
N_ESTIMATORS = 2000          # 最大学習回数
# N_ESTIMATORS = 20          # 最大学習回数
VERBOSE = 100               # 300回ごとに評価する
EARLY_STOPPING_ROUNDS = 50  # 200回の学習でよくならなければ、学習をとめる
# N_JOBS = multiprocessing.cpu_count() - 2
# N_JOBS = 6
# N_FOLD = 4
# KFOLD_SEED = 0

N_JOBS = 73 
N_FOLD = 5
KFOLD_SEED = 42

# lgbm_params
# lgbm_params = {
#               'objective': 'regression',
#               "metric": 'rmse',
# #               'reg_alpha': 0.1,
# #               'reg_lambda': 0.1,
#               "boosting_type": "gbdt",
#               'learning_rate': 0.1,
#               'n_jobs': N_JOBS,
# #               "subsample_freq": 1,
# #               "subsample": 1,
#               "bagging_seed": 2,
# #               "verbosity": -1,
#     'num_leaves': 51, 'max_depth': 158, 'min_chiled_samples': 15, 'min_chiled_weight': 1, 'learning_rate': 0.07, 'colsample_bytree': 0.8
#              }

# nb015
# lgbm_params = {'boosting_type': 'gbdt',
#           'metric': 'rmse',
#           'objective': 'regression',
#           'n_jobs': N_JOBS,
#           'seed': 236,
#           'num_leaves': 280,
#           'learning_rate': 0.026623466966581126,
#           'max_depth': 73,
#           'lambda_l1': 2.959759088169741,
#           'lambda_l2': 1.331172832164913,
#           'bagging_fraction': 0.9655406551472153,
#           'bagging_freq': 9,
#           'colsample_bytree': 0.6867118652742716}

# nb019
# lgbm_params = {
#     'objective': 'regression',
#     "metric": 'rmse',
#     "boosting_type": "gbdt",
#     'learning_rate': 0.1,
#     'n_jobs': N_JOBS,
#     'max_depth': 85, 
#     'min_chiled_samples': 62, 
#     'min_chiled_weight': 10, 
#     'learning_rate': 0.20158497791184515, 
#     'colsample_bytree': 1.0,
    
#           'lambda_l1': 2.959759088169741,
#           'lambda_l2': 1.331172832164913,
# #           'bagging_fraction': 0.9655406551472153,
# #           'bagging_freq': 9,
# }

# https://www.kaggle.com/nxrprime/single-model-lgbm-kalman-filter-ii
lgbm_params = {'boosting_type': 'gbdt',
          'metric': 'rmse',
          'objective': 'regression',
          'n_jobs': N_JOBS,
          'seed': 236,
          'num_leaves': 280,
#           'learning_rate': 0.026623466966581126,
          'learning_rate': 0.03,
          'max_depth': 73,
          'lambda_l1': 2.959759088169741,
          'lambda_l2': 1.331172832164913,
          'bagging_fraction': 0.9655406551472153,
          'bagging_freq': 9,
          'colsample_bytree': 0.6867118652742716}

# %% [markdown]
# ## groupごとに学習

# %% [raw]
# # X_te['group'][np.arange(len(X_te))<20000] = 4
# a = np.zeros(len(X_te))

# %% [raw]
# a[1000:1100] = 1
# X_te['group'] = a
# plt.plot(X_te['group'])

# %%
# %%time

test_pred_round = np.zeros(len(X_te))
test_pred = np.zeros(len(X_te))
oof_round = np.zeros(len(X))
oof = np.zeros(len(X))

for group in sorted(X['group'].unique()):
    print(f'***************************** group {group} ({time.ctime()}) *******************')
    idxs_tr = X['group'] == group
    _X, _y = X[idxs_tr], y[idxs_tr]
    
    idxs_te = X_te['group'] == group
    _X_te = X_te[idxs_te]
    
    test_pred_round_grp, test_pred_grp, oof_round_grp, oof_grp, model_name = train_lgbm(_X, _y, _X_te, lgbm_params,
                                                            n_fold=N_FOLD, 
                                                            verbose=VERBOSE, 
                                                            random_state=KFOLD_SEED, 
                                                            early_stopping_rounds=EARLY_STOPPING_ROUNDS, 
                                                            show_fig=True
                                                           )
    test_pred_round[idxs_te] = test_pred_round_grp
    test_pred[idxs_te] = test_pred_grp
    oof_round[idxs_tr] = oof_round_grp
    oof[idxs_tr] = oof_grp


print('')
print('finish group train')
print(f'oof score(f1_macro): {f1_score(y, oof_round, average="macro"):.4f}')
# Out:
# ***************************** group 0 (Sun May  3 18:06:59 2020) *******************
# features(64):
# Index(['signal', 'grad_1', 'grad_2', 'grad_3', 'grad_4', 'lowpass_ff_0.0100',
#        'lowpass_lf_0.0239', 'lowpass_ff_0.0570', 'lowpass_ff_0.3244',
#        'highpass_lf_0.0100', 'highpass_ff_0.0100', 'highpass_lf_0.0163',
#        'highpass_lf_0.0264', 'highpass_ff_0.0264', 'highpass_lf_0.0430',
#        'highpass_lf_0.0699', 'highpass_lf_0.1136', 'highpass_ff_0.1136',
#        'highpass_lf_0.1848', 'highpass_ff_0.1848', 'highpass_lf_0.3005',
#        'highpass_ff_0.3005', 'highpass_lf_0.4885', 'highpass_ff_0.4885',
#        'highpass_lf_0.7943', 'highpass_ff_0.7943', 'roll_std_10',
#        'roll_min_10', 'roll_max_10', 'roll_range_10', 'roll_q10_10',
#        'roll_q50_10', 'roll_std_50', 'roll_min_50', 'roll_range_50',
#        'roll_q10_50', 'roll_q25_50', 'roll_q50_50', 'roll_std_100',
#        'roll_min_100', 'roll_max_100', 'roll_range_100', 'roll_q10_100',
#        'roll_q25_100', 'roll_std_500', 'roll_min_500', 'roll_range_500',
#        'roll_q10_500', 'roll_q25_500', 'roll_std_1000', 'roll_min_1000',
#        'roll_range_1000', 'roll_q10_1000', 'roll_q25_1000', 'roll_std_3000',
#        'roll_min_3000', 'roll_max_3000', 'roll_range_3000', 'roll_q10_3000',
#        'ewm_std_10', 'ewm_std_50', 'ewm_std_100', 'signal', 'group'],
#       dtype='object')
#
# ------------------
# - Fold 1/5 started at Sun May  3 18:07:00 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0174776	valid_1's rmse: 0.0192703
# [200]	training's rmse: 0.0131228	valid_1's rmse: 0.0171333
# Early stopping, best iteration is:
# [188]	training's rmse: 0.0133732	valid_1's rmse: 0.0171163
# ---> f1-score(macro) valid: 0.9971
#
#
# ------------------
# - Fold 2/5 started at Sun May  3 18:07:37 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0176086	valid_1's rmse: 0.0185454
# [200]	training's rmse: 0.013136	valid_1's rmse: 0.0160398
# [300]	training's rmse: 0.0113098	valid_1's rmse: 0.0159686
# Early stopping, best iteration is:
# [322]	training's rmse: 0.0109799	valid_1's rmse: 0.0159587
# ---> f1-score(macro) valid: 0.9976
#
#
# ------------------
# - Fold 3/5 started at Sun May  3 18:08:35 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0172996	valid_1's rmse: 0.0212425
# [200]	training's rmse: 0.0127372	valid_1's rmse: 0.0190401
# [300]	training's rmse: 0.0109603	valid_1's rmse: 0.0189048
# Early stopping, best iteration is:
# [326]	training's rmse: 0.010606	valid_1's rmse: 0.0188904
# ---> f1-score(macro) valid: 0.9967
#
#
# ------------------
# - Fold 4/5 started at Sun May  3 18:09:28 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0175351	valid_1's rmse: 0.0200274
# [200]	training's rmse: 0.0130725	valid_1's rmse: 0.0177234
# [300]	training's rmse: 0.011201	valid_1's rmse: 0.0176592
# Early stopping, best iteration is:
# [265]	training's rmse: 0.011779	valid_1's rmse: 0.0176505
# ---> f1-score(macro) valid: 0.9972
#
#
# ------------------
# - Fold 5/5 started at Sun May  3 18:10:13 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0179059	valid_1's rmse: 0.0176491
# [200]	training's rmse: 0.0134885	valid_1's rmse: 0.0152059
# Early stopping, best iteration is:
# [247]	training's rmse: 0.0126121	valid_1's rmse: 0.0151792
# ---> f1-score(macro) valid: 0.9977
#
# ====== finish ======
# score list: [0.9970590653941244, 0.9976067281315646, 0.9966846502142861, 0.9972404215272674, 0.9976829046674593]
# CV mean score(f1_macro): 0.9973, std: 0.0004
# oof score(f1_macro): 0.9973
# group_score(0): 0.997255
# ***************************** group 1 (Sun May  3 18:11:09 2020) *******************
# features(64):
# Index(['signal', 'grad_1', 'grad_2', 'grad_3', 'grad_4', 'lowpass_ff_0.0100',
#        'lowpass_lf_0.0239', 'lowpass_ff_0.0570', 'lowpass_ff_0.3244',
#        'highpass_lf_0.0100', 'highpass_ff_0.0100', 'highpass_lf_0.0163',
#        'highpass_lf_0.0264', 'highpass_ff_0.0264', 'highpass_lf_0.0430',
#        'highpass_lf_0.0699', 'highpass_lf_0.1136', 'highpass_ff_0.1136',
#        'highpass_lf_0.1848', 'highpass_ff_0.1848', 'highpass_lf_0.3005',
#        'highpass_ff_0.3005', 'highpass_lf_0.4885', 'highpass_ff_0.4885',
#        'highpass_lf_0.7943', 'highpass_ff_0.7943', 'roll_std_10',
#        'roll_min_10', 'roll_max_10', 'roll_range_10', 'roll_q10_10',
#        'roll_q50_10', 'roll_std_50', 'roll_min_50', 'roll_range_50',
#        'roll_q10_50', 'roll_q25_50', 'roll_q50_50', 'roll_std_100',
#        'roll_min_100', 'roll_max_100', 'roll_range_100', 'roll_q10_100',
#        'roll_q25_100', 'roll_std_500', 'roll_min_500', 'roll_range_500',
#        'roll_q10_500', 'roll_q25_500', 'roll_std_1000', 'roll_min_1000',
#        'roll_range_1000', 'roll_q10_1000', 'roll_q25_1000', 'roll_std_3000',
#        'roll_min_3000', 'roll_max_3000', 'roll_range_3000', 'roll_q10_3000',
#        'ewm_std_10', 'ewm_std_50', 'ewm_std_100', 'signal', 'group'],
#       dtype='object')
#
# ------------------
# - Fold 1/5 started at Sun May  3 18:11:10 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.130752	valid_1's rmse: 0.140989
# [200]	training's rmse: 0.116484	valid_1's rmse: 0.133532
# [300]	training's rmse: 0.110587	valid_1's rmse: 0.132042
# [400]	training's rmse: 0.106542	valid_1's rmse: 0.131379
# [500]	training's rmse: 0.103158	valid_1's rmse: 0.131149
# [600]	training's rmse: 0.100291	valid_1's rmse: 0.130939
# [700]	training's rmse: 0.0977713	valid_1's rmse: 0.130786
# [800]	training's rmse: 0.0953721	valid_1's rmse: 0.130624
# [900]	training's rmse: 0.0931671	valid_1's rmse: 0.130533
# [1000]	training's rmse: 0.0909893	valid_1's rmse: 0.130467
# [1100]	training's rmse: 0.0887967	valid_1's rmse: 0.130436
# [1200]	training's rmse: 0.0867374	valid_1's rmse: 0.130426
# Early stopping, best iteration is:
# [1185]	training's rmse: 0.0870398	valid_1's rmse: 0.130414
# ---> f1-score(macro) valid: 0.9745
#
#
# ------------------
# - Fold 2/5 started at Sun May  3 18:13:57 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.130764	valid_1's rmse: 0.140462
# [200]	training's rmse: 0.116443	valid_1's rmse: 0.133136
# [300]	training's rmse: 0.110534	valid_1's rmse: 0.131609
# [400]	training's rmse: 0.106455	valid_1's rmse: 0.130973
# [500]	training's rmse: 0.102989	valid_1's rmse: 0.130544
# [600]	training's rmse: 0.100099	valid_1's rmse: 0.130263
# [700]	training's rmse: 0.0975289	valid_1's rmse: 0.130014
# [800]	training's rmse: 0.0951518	valid_1's rmse: 0.129822
# [900]	training's rmse: 0.0929845	valid_1's rmse: 0.129664
# [1000]	training's rmse: 0.0908335	valid_1's rmse: 0.129535
# [1100]	training's rmse: 0.0887852	valid_1's rmse: 0.129483
# [1200]	training's rmse: 0.0868456	valid_1's rmse: 0.129435
# [1300]	training's rmse: 0.0850948	valid_1's rmse: 0.129365
# [1400]	training's rmse: 0.083378	valid_1's rmse: 0.12934
# [1500]	training's rmse: 0.0815772	valid_1's rmse: 0.129295
# [1600]	training's rmse: 0.0800399	valid_1's rmse: 0.129251
# Early stopping, best iteration is:
# [1607]	training's rmse: 0.0799469	valid_1's rmse: 0.129247
# ---> f1-score(macro) valid: 0.9744
#
#
# ------------------
# - Fold 3/5 started at Sun May  3 18:17:49 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.130237	valid_1's rmse: 0.142434
# [200]	training's rmse: 0.116032	valid_1's rmse: 0.135251
# [300]	training's rmse: 0.109998	valid_1's rmse: 0.133641
# [400]	training's rmse: 0.105893	valid_1's rmse: 0.133054
# [500]	training's rmse: 0.102512	valid_1's rmse: 0.132731
# [600]	training's rmse: 0.0996743	valid_1's rmse: 0.13244
# [700]	training's rmse: 0.0970086	valid_1's rmse: 0.132314
# [800]	training's rmse: 0.0946731	valid_1's rmse: 0.132215
# [900]	training's rmse: 0.0923586	valid_1's rmse: 0.132146
# [1000]	training's rmse: 0.0902308	valid_1's rmse: 0.132065
# [1100]	training's rmse: 0.0882002	valid_1's rmse: 0.132033
# [1200]	training's rmse: 0.0863407	valid_1's rmse: 0.131998
# [1300]	training's rmse: 0.0845414	valid_1's rmse: 0.131952
# [1400]	training's rmse: 0.082694	valid_1's rmse: 0.131934
# [1500]	training's rmse: 0.0809484	valid_1's rmse: 0.131899
# [1600]	training's rmse: 0.0794463	valid_1's rmse: 0.131881
# [1700]	training's rmse: 0.0778118	valid_1's rmse: 0.131881
# Early stopping, best iteration is:
# [1741]	training's rmse: 0.0771463	valid_1's rmse: 0.131868
# ---> f1-score(macro) valid: 0.9735
#
#
# ------------------
# - Fold 4/5 started at Sun May  3 18:21:43 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.130379	valid_1's rmse: 0.141862
# [200]	training's rmse: 0.116114	valid_1's rmse: 0.134826
# [300]	training's rmse: 0.110251	valid_1's rmse: 0.133412
# [400]	training's rmse: 0.10618	valid_1's rmse: 0.132838
# [500]	training's rmse: 0.102792	valid_1's rmse: 0.132438
# [600]	training's rmse: 0.0999108	valid_1's rmse: 0.132225
# [700]	training's rmse: 0.0973354	valid_1's rmse: 0.132102
# [800]	training's rmse: 0.094987	valid_1's rmse: 0.132008
# [900]	training's rmse: 0.0927584	valid_1's rmse: 0.131885
# [1000]	training's rmse: 0.0906361	valid_1's rmse: 0.131848
# [1100]	training's rmse: 0.088729	valid_1's rmse: 0.131776
# [1200]	training's rmse: 0.0869355	valid_1's rmse: 0.131728
# [1300]	training's rmse: 0.0849772	valid_1's rmse: 0.131713
# Early stopping, best iteration is:
# [1327]	training's rmse: 0.084372	valid_1's rmse: 0.131707
# ---> f1-score(macro) valid: 0.9739
#
#
# ------------------
# - Fold 5/5 started at Sun May  3 18:24:54 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.130682	valid_1's rmse: 0.140934
# [200]	training's rmse: 0.116376	valid_1's rmse: 0.13388
# [300]	training's rmse: 0.110285	valid_1's rmse: 0.132316
# [400]	training's rmse: 0.10624	valid_1's rmse: 0.131786
# [500]	training's rmse: 0.102878	valid_1's rmse: 0.131514
# [600]	training's rmse: 0.100021	valid_1's rmse: 0.131261
# [700]	training's rmse: 0.0973915	valid_1's rmse: 0.13106
# [800]	training's rmse: 0.0949401	valid_1's rmse: 0.130913
# [900]	training's rmse: 0.0926314	valid_1's rmse: 0.130809
# [1000]	training's rmse: 0.0904908	valid_1's rmse: 0.130754
# [1100]	training's rmse: 0.0884408	valid_1's rmse: 0.130676
# [1200]	training's rmse: 0.0867187	valid_1's rmse: 0.130601
# [1300]	training's rmse: 0.0848636	valid_1's rmse: 0.130565
# Early stopping, best iteration is:
# [1328]	training's rmse: 0.0843581	valid_1's rmse: 0.130548
# ---> f1-score(macro) valid: 0.9745
#
# ====== finish ======
# score list: [0.9744629430227948, 0.974423637728455, 0.9734864947708716, 0.9738666587392325, 0.9745356665730753]
# CV mean score(f1_macro): 0.9742, std: 0.0004
# oof score(f1_macro): 0.9742
# group_score(1): 0.974156
# ***************************** group 2 (Sun May  3 18:27:59 2020) *******************
# features(64):
# Index(['signal', 'grad_1', 'grad_2', 'grad_3', 'grad_4', 'lowpass_ff_0.0100',
#        'lowpass_lf_0.0239', 'lowpass_ff_0.0570', 'lowpass_ff_0.3244',
#        'highpass_lf_0.0100', 'highpass_ff_0.0100', 'highpass_lf_0.0163',
#        'highpass_lf_0.0264', 'highpass_ff_0.0264', 'highpass_lf_0.0430',
#        'highpass_lf_0.0699', 'highpass_lf_0.1136', 'highpass_ff_0.1136',
#        'highpass_lf_0.1848', 'highpass_ff_0.1848', 'highpass_lf_0.3005',
#        'highpass_ff_0.3005', 'highpass_lf_0.4885', 'highpass_ff_0.4885',
#        'highpass_lf_0.7943', 'highpass_ff_0.7943', 'roll_std_10',
#        'roll_min_10', 'roll_max_10', 'roll_range_10', 'roll_q10_10',
#        'roll_q50_10', 'roll_std_50', 'roll_min_50', 'roll_range_50',
#        'roll_q10_50', 'roll_q25_50', 'roll_q50_50', 'roll_std_100',
#        'roll_min_100', 'roll_max_100', 'roll_range_100', 'roll_q10_100',
#        'roll_q25_100', 'roll_std_500', 'roll_min_500', 'roll_range_500',
#        'roll_q10_500', 'roll_q25_500', 'roll_std_1000', 'roll_min_1000',
#        'roll_range_1000', 'roll_q10_1000', 'roll_q25_1000', 'roll_std_3000',
#        'roll_min_3000', 'roll_max_3000', 'roll_range_3000', 'roll_q10_3000',
#        'ewm_std_10', 'ewm_std_50', 'ewm_std_100', 'signal', 'group'],
#       dtype='object')
#
# ------------------
# - Fold 1/5 started at Sun May  3 18:28:00 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.133992	valid_1's rmse: 0.139698
# [200]	training's rmse: 0.119233	valid_1's rmse: 0.130565
# [300]	training's rmse: 0.115314	valid_1's rmse: 0.1303
# [400]	training's rmse: 0.112646	valid_1's rmse: 0.130185
# [500]	training's rmse: 0.110254	valid_1's rmse: 0.130125
# [600]	training's rmse: 0.108023	valid_1's rmse: 0.130062
# Early stopping, best iteration is:
# [618]	training's rmse: 0.107597	valid_1's rmse: 0.130057
# ---> f1-score(macro) valid: 0.9690
#
#
# ------------------
# - Fold 2/5 started at Sun May  3 18:29:43 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.133903	valid_1's rmse: 0.139856
# [200]	training's rmse: 0.119123	valid_1's rmse: 0.130647
# [300]	training's rmse: 0.115118	valid_1's rmse: 0.130328
# [400]	training's rmse: 0.112216	valid_1's rmse: 0.130211
# [500]	training's rmse: 0.109806	valid_1's rmse: 0.130152
# [600]	training's rmse: 0.107685	valid_1's rmse: 0.130123
# [700]	training's rmse: 0.105642	valid_1's rmse: 0.130086
# [800]	training's rmse: 0.103675	valid_1's rmse: 0.130041
# [900]	training's rmse: 0.101784	valid_1's rmse: 0.130038
# Early stopping, best iteration is:
# [883]	training's rmse: 0.102074	valid_1's rmse: 0.130031
# ---> f1-score(macro) valid: 0.9700
#
#
# ------------------
# - Fold 3/5 started at Sun May  3 18:32:04 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.13402	valid_1's rmse: 0.139918
# [200]	training's rmse: 0.119275	valid_1's rmse: 0.130559
# [300]	training's rmse: 0.115252	valid_1's rmse: 0.130223
# [400]	training's rmse: 0.112442	valid_1's rmse: 0.130116
# [500]	training's rmse: 0.110052	valid_1's rmse: 0.130037
# [600]	training's rmse: 0.107976	valid_1's rmse: 0.129992
# [700]	training's rmse: 0.105847	valid_1's rmse: 0.129969
# [800]	training's rmse: 0.103858	valid_1's rmse: 0.12995
# Early stopping, best iteration is:
# [812]	training's rmse: 0.103651	valid_1's rmse: 0.129941
# ---> f1-score(macro) valid: 0.9680
#
#
# ------------------
# - Fold 4/5 started at Sun May  3 18:34:12 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.133656	valid_1's rmse: 0.140764
# [200]	training's rmse: 0.118703	valid_1's rmse: 0.131695
# [300]	training's rmse: 0.114818	valid_1's rmse: 0.131392
# [400]	training's rmse: 0.112049	valid_1's rmse: 0.13128
# [500]	training's rmse: 0.109716	valid_1's rmse: 0.131224
# [600]	training's rmse: 0.107626	valid_1's rmse: 0.131183
# [700]	training's rmse: 0.105609	valid_1's rmse: 0.131167
# Early stopping, best iteration is:
# [653]	training's rmse: 0.106568	valid_1's rmse: 0.131166
# ---> f1-score(macro) valid: 0.9675
#
#
# ------------------
# - Fold 5/5 started at Sun May  3 18:36:05 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.13394	valid_1's rmse: 0.140465
# [200]	training's rmse: 0.119198	valid_1's rmse: 0.131094
# [300]	training's rmse: 0.115368	valid_1's rmse: 0.130787
# [400]	training's rmse: 0.112687	valid_1's rmse: 0.130676
# [500]	training's rmse: 0.110178	valid_1's rmse: 0.130615
# [600]	training's rmse: 0.107977	valid_1's rmse: 0.130591
# [700]	training's rmse: 0.105844	valid_1's rmse: 0.13057
# Early stopping, best iteration is:
# [707]	training's rmse: 0.105697	valid_1's rmse: 0.130569
# ---> f1-score(macro) valid: 0.9696
#
# ====== finish ======
# score list: [0.9689709243629823, 0.9699771022965233, 0.9680327811323027, 0.9674798312274974, 0.969634890968532]
# CV mean score(f1_macro): 0.9688, std: 0.0009
# oof score(f1_macro): 0.9688
# group_score(2): 0.968817
# ***************************** group 3 (Sun May  3 18:38:33 2020) *******************
# features(64):
# Index(['signal', 'grad_1', 'grad_2', 'grad_3', 'grad_4', 'lowpass_ff_0.0100',
#        'lowpass_lf_0.0239', 'lowpass_ff_0.0570', 'lowpass_ff_0.3244',
#        'highpass_lf_0.0100', 'highpass_ff_0.0100', 'highpass_lf_0.0163',
#        'highpass_lf_0.0264', 'highpass_ff_0.0264', 'highpass_lf_0.0430',
#        'highpass_lf_0.0699', 'highpass_lf_0.1136', 'highpass_ff_0.1136',
#        'highpass_lf_0.1848', 'highpass_ff_0.1848', 'highpass_lf_0.3005',
#        'highpass_ff_0.3005', 'highpass_lf_0.4885', 'highpass_ff_0.4885',
#        'highpass_lf_0.7943', 'highpass_ff_0.7943', 'roll_std_10',
#        'roll_min_10', 'roll_max_10', 'roll_range_10', 'roll_q10_10',
#        'roll_q50_10', 'roll_std_50', 'roll_min_50', 'roll_range_50',
#        'roll_q10_50', 'roll_q25_50', 'roll_q50_50', 'roll_std_100',
#        'roll_min_100', 'roll_max_100', 'roll_range_100', 'roll_q10_100',
#        'roll_q25_100', 'roll_std_500', 'roll_min_500', 'roll_range_500',
#        'roll_q10_500', 'roll_q25_500', 'roll_std_1000', 'roll_min_1000',
#        'roll_range_1000', 'roll_q10_1000', 'roll_q25_1000', 'roll_std_3000',
#        'roll_min_3000', 'roll_max_3000', 'roll_range_3000', 'roll_q10_3000',
#        'ewm_std_10', 'ewm_std_50', 'ewm_std_100', 'signal', 'group'],
#       dtype='object')
#
# ------------------
# - Fold 1/5 started at Sun May  3 18:38:33 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0438873	valid_1's rmse: 0.0484002
# [200]	training's rmse: 0.0338093	valid_1's rmse: 0.0436089
# [300]	training's rmse: 0.0285626	valid_1's rmse: 0.0435218
# Early stopping, best iteration is:
# [338]	training's rmse: 0.0270682	valid_1's rmse: 0.0435153
# ---> f1-score(macro) valid: 0.9968
#
#
# ------------------
# - Fold 2/5 started at Sun May  3 18:39:38 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0441953	valid_1's rmse: 0.0469352
# [200]	training's rmse: 0.0343106	valid_1's rmse: 0.0419971
# Early stopping, best iteration is:
# [202]	training's rmse: 0.0341786	valid_1's rmse: 0.041992
# ---> f1-score(macro) valid: 0.9969
#
#
# ------------------
# - Fold 3/5 started at Sun May  3 18:40:23 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0439677	valid_1's rmse: 0.0475671
# [200]	training's rmse: 0.0341973	valid_1's rmse: 0.0426742
# [300]	training's rmse: 0.0289965	valid_1's rmse: 0.042575
# Early stopping, best iteration is:
# [311]	training's rmse: 0.0285311	valid_1's rmse: 0.0425579
# ---> f1-score(macro) valid: 0.9970
#
#
# ------------------
# - Fold 4/5 started at Sun May  3 18:41:32 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0445329	valid_1's rmse: 0.0466139
# [200]	training's rmse: 0.0347225	valid_1's rmse: 0.0411421
# Early stopping, best iteration is:
# [238]	training's rmse: 0.0323714	valid_1's rmse: 0.0410683
# ---> f1-score(macro) valid: 0.9970
#
#
# ------------------
# - Fold 5/5 started at Sun May  3 18:42:25 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.0443988	valid_1's rmse: 0.0471162
# [200]	training's rmse: 0.0342167	valid_1's rmse: 0.0420584
# [300]	training's rmse: 0.0289079	valid_1's rmse: 0.0419533
# Early stopping, best iteration is:
# [258]	training's rmse: 0.0309132	valid_1's rmse: 0.041947
# ---> f1-score(macro) valid: 0.9969
#
# ====== finish ======
# score list: [0.9967732616796181, 0.996918990935536, 0.9969874805421464, 0.9970325476017701, 0.9969261845857372]
# CV mean score(f1_macro): 0.9969, std: 0.0001
# oof score(f1_macro): 0.9969
# group_score(3): 0.996928
# ***************************** group 4 (Sun May  3 18:43:33 2020) *******************
# features(64):
# Index(['signal', 'grad_1', 'grad_2', 'grad_3', 'grad_4', 'lowpass_ff_0.0100',
#        'lowpass_lf_0.0239', 'lowpass_ff_0.0570', 'lowpass_ff_0.3244',
#        'highpass_lf_0.0100', 'highpass_ff_0.0100', 'highpass_lf_0.0163',
#        'highpass_lf_0.0264', 'highpass_ff_0.0264', 'highpass_lf_0.0430',
#        'highpass_lf_0.0699', 'highpass_lf_0.1136', 'highpass_ff_0.1136',
#        'highpass_lf_0.1848', 'highpass_ff_0.1848', 'highpass_lf_0.3005',
#        'highpass_ff_0.3005', 'highpass_lf_0.4885', 'highpass_ff_0.4885',
#        'highpass_lf_0.7943', 'highpass_ff_0.7943', 'roll_std_10',
#        'roll_min_10', 'roll_max_10', 'roll_range_10', 'roll_q10_10',
#        'roll_q50_10', 'roll_std_50', 'roll_min_50', 'roll_range_50',
#        'roll_q10_50', 'roll_q25_50', 'roll_q50_50', 'roll_std_100',
#        'roll_min_100', 'roll_max_100', 'roll_range_100', 'roll_q10_100',
#        'roll_q25_100', 'roll_std_500', 'roll_min_500', 'roll_range_500',
#        'roll_q10_500', 'roll_q25_500', 'roll_std_1000', 'roll_min_1000',
#        'roll_range_1000', 'roll_q10_1000', 'roll_q25_1000', 'roll_std_3000',
#        'roll_min_3000', 'roll_max_3000', 'roll_range_3000', 'roll_q10_3000',
#        'ewm_std_10', 'ewm_std_50', 'ewm_std_100', 'signal', 'group'],
#       dtype='object')
#
# ------------------
# - Fold 1/5 started at Sun May  3 18:43:34 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.290825	valid_1's rmse: 0.295245
# [200]	training's rmse: 0.27797	valid_1's rmse: 0.287015
# [300]	training's rmse: 0.274682	valid_1's rmse: 0.286682
# [400]	training's rmse: 0.272003	valid_1's rmse: 0.286503
# [500]	training's rmse: 0.269434	valid_1's rmse: 0.286352
# [600]	training's rmse: 0.267121	valid_1's rmse: 0.286236
# [700]	training's rmse: 0.26489	valid_1's rmse: 0.286154
# [800]	training's rmse: 0.262634	valid_1's rmse: 0.2861
# [900]	training's rmse: 0.260471	valid_1's rmse: 0.28603
# [1000]	training's rmse: 0.258291	valid_1's rmse: 0.285986
# Early stopping, best iteration is:
# [1017]	training's rmse: 0.257909	valid_1's rmse: 0.285972
# ---> f1-score(macro) valid: 0.7822
#
#
# ------------------
# - Fold 2/5 started at Sun May  3 18:46:11 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.290402	valid_1's rmse: 0.297227
# [200]	training's rmse: 0.277573	valid_1's rmse: 0.288772
# [300]	training's rmse: 0.274343	valid_1's rmse: 0.28838
# [400]	training's rmse: 0.271658	valid_1's rmse: 0.288147
# [500]	training's rmse: 0.269219	valid_1's rmse: 0.28801
# [600]	training's rmse: 0.266889	valid_1's rmse: 0.287915
# [700]	training's rmse: 0.264605	valid_1's rmse: 0.287827
# [800]	training's rmse: 0.262416	valid_1's rmse: 0.28776
# [900]	training's rmse: 0.260166	valid_1's rmse: 0.287729
# [1000]	training's rmse: 0.258131	valid_1's rmse: 0.287695
# [1100]	training's rmse: 0.256053	valid_1's rmse: 0.287627
# [1200]	training's rmse: 0.253981	valid_1's rmse: 0.287594
# [1300]	training's rmse: 0.252118	valid_1's rmse: 0.287589
# [1400]	training's rmse: 0.250093	valid_1's rmse: 0.287561
# Early stopping, best iteration is:
# [1373]	training's rmse: 0.250628	valid_1's rmse: 0.287557
# ---> f1-score(macro) valid: 0.8617
#
#
# ------------------
# - Fold 3/5 started at Sun May  3 18:49:26 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.290863	valid_1's rmse: 0.295605
# [200]	training's rmse: 0.278033	valid_1's rmse: 0.286952
# [300]	training's rmse: 0.274815	valid_1's rmse: 0.286568
# [400]	training's rmse: 0.272228	valid_1's rmse: 0.286378
# [500]	training's rmse: 0.269839	valid_1's rmse: 0.28624
# [600]	training's rmse: 0.267465	valid_1's rmse: 0.28612
# [700]	training's rmse: 0.265214	valid_1's rmse: 0.28604
# [800]	training's rmse: 0.263095	valid_1's rmse: 0.28599
# [900]	training's rmse: 0.260899	valid_1's rmse: 0.285905
# [1000]	training's rmse: 0.258702	valid_1's rmse: 0.285849
# [1100]	training's rmse: 0.256682	valid_1's rmse: 0.285836
# [1200]	training's rmse: 0.254695	valid_1's rmse: 0.285806
# Early stopping, best iteration is:
# [1210]	training's rmse: 0.254482	valid_1's rmse: 0.285798
# ---> f1-score(macro) valid: 0.8717
#
#
# ------------------
# - Fold 4/5 started at Sun May  3 18:52:49 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.290914	valid_1's rmse: 0.295174
# [200]	training's rmse: 0.278129	valid_1's rmse: 0.286628
# [300]	training's rmse: 0.274851	valid_1's rmse: 0.286303
# [400]	training's rmse: 0.272264	valid_1's rmse: 0.286139
# [500]	training's rmse: 0.26975	valid_1's rmse: 0.28601
# [600]	training's rmse: 0.267402	valid_1's rmse: 0.285903
# [700]	training's rmse: 0.26508	valid_1's rmse: 0.285825
# [800]	training's rmse: 0.262815	valid_1's rmse: 0.285749
# [900]	training's rmse: 0.260715	valid_1's rmse: 0.285697
# [1000]	training's rmse: 0.258611	valid_1's rmse: 0.285681
# [1100]	training's rmse: 0.256508	valid_1's rmse: 0.285626
# [1200]	training's rmse: 0.254478	valid_1's rmse: 0.28561
# Early stopping, best iteration is:
# [1151]	training's rmse: 0.255469	valid_1's rmse: 0.285606
# ---> f1-score(macro) valid: 0.7656
#
#
# ------------------
# - Fold 5/5 started at Sun May  3 18:55:35 2020
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 0.290731	valid_1's rmse: 0.295796
# [200]	training's rmse: 0.277912	valid_1's rmse: 0.287402
# [300]	training's rmse: 0.274622	valid_1's rmse: 0.287046
# [400]	training's rmse: 0.271964	valid_1's rmse: 0.286837
# [500]	training's rmse: 0.269478	valid_1's rmse: 0.286702
# [600]	training's rmse: 0.267125	valid_1's rmse: 0.286631
# [700]	training's rmse: 0.264845	valid_1's rmse: 0.286543
# [800]	training's rmse: 0.262651	valid_1's rmse: 0.286487
# [900]	training's rmse: 0.260494	valid_1's rmse: 0.286422
# [1000]	training's rmse: 0.258552	valid_1's rmse: 0.286374
# [1100]	training's rmse: 0.256408	valid_1's rmse: 0.286337
# Early stopping, best iteration is:
# [1117]	training's rmse: 0.256047	valid_1's rmse: 0.286335
# ---> f1-score(macro) valid: 0.8684
#
# ====== finish ======
# score list: [0.7822091553076944, 0.8617440071692313, 0.8717229218487148, 0.7655805564031614, 0.8683682347678776]
# CV mean score(f1_macro): 0.8299, std: 0.0462
# oof score(f1_macro): 0.7827
# group_score(4): 0.782668
# finish group train
# oof score(f1_macro): 0.9389
# CPU times: user 2d 48min 12s, sys: 22min 36s, total: 2d 1h 10min 48s
# Wall time: 51min 42s

# %% [markdown]
# <br>
#
# group ごとのスコア

# %%
for group in sorted(X['group'].unique()):
    idxs = X['group'] == group
    oof_round_grp = oof_round[idxs].astype(int)
    y_grp = y[idxs]
    print(f'group_score({group}): {f1_macro(y_grp, oof_round_grp):4f}')
# Out:
# group_score(0): 0.997255
# group_score(1): 0.974156
# group_score(2): 0.968817
# group_score(3): 0.996928
# group_score(4): 0.782668

# %% [markdown]
# # save

# %% [markdown]
# submission

# %%
save_path = f'{DIR_OUTPUT}submission_nb{NB}_{model_name}_cv_{f1_macro(y, oof_round):.4f}.csv'
sub = pd.read_csv(PATH_SMPLE_SUB)
sub['open_channels'] = test_pred_round.astype(int)
print(f'save path: {save_path}')
# Out:
# save path: ./../data/output/submission_nb029_LGBMRegressor_cv_0.9389.csv

# %%
sub.to_csv(save_path, index=False, float_format='%.4f')

# %% [markdown]
# <br>
#
# output_ignore

# %% [markdown]
# # analysis

# %% [markdown]
# <br>
# 間違えたところの可視化

# %%
x_idx = np.arange(len(X))
idxs = y != oof_round

failed = np.zeros(len(X))
failed[idxs] = 1

# %%
n = 200
b = np.ones(n)/n
failed_move = np.convolve(failed, b, mode='same')

# %%
fig, axs = plt.subplots(2, 1, figsize=(20, 6))
axs = axs.ravel()
# fig = plt.figure(figsize=(20, 3))

for i_gr, group in enumerate(sorted(X['group'].unique())):
    idxs = X['group'] == group
    axs[0].plot(np.arange(len(X))[idxs], X['signal'].values[idxs], color=cp[i_gr], label=f'group={group}')
for x in range(10): 
    axs[0].axvline(x*500000 + 500000, color='gray') 
    axs[0].text(x*500000 + 250000, 0.6, x)
axs[0].plot(x_idx, failed_move, '.', color='black', label='failed_mv')
axs[0].set_xlim(0, 5500000)
axs[0].legend()

axs[1].plot(x_idx, y)
axs[1].set_xlim(0, 5500000)

# fig.legend()
# Out:
# (0, 5500000)

# %% [markdown]
# > やっぱり、group 4 がひときわ悪いね
